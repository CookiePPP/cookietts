# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import os
os.environ["LRU_CACHE_CAPACITY"] = "3"
import random

from CookieTTS.utils.dataset.utils import load_wav_to_torch, load_filepaths_and_text

# %%
import os
import random
from glob import glob
from CookieTTS.utils.dataset.utils import load_wav_to_torch
from CookieTTS.utils.audio.stft import STFT
from CookieTTS.utils.audio.audio_processing import window_sumsquare, dynamic_range_compression, dynamic_range_decompression

class AudioDataset(torch.utils.data.Dataset):
    def __init__(self, model_config):
        
        self.win_lens = model_config['window_lengths']
        self.hop_len = model_config['hop_length']
        self.fil_len = model_config['filter_length']
        
        self.stfts = []
        for win_len in self.win_lens:
            stft = STFT(filter_length=self.fil_len,
                           hop_length=self.hop_len,
                           win_length=win_len,)
            self.stfts.append(stft)
    
    def get_mel(self, audio):
        """Take audio and convert to multi-res spectrogram"""
        melspec = []
        for stft in self.stfts:
            spect = stft.transform(audio.unsqueeze(0), return_phase=False)[0].squeeze(0)# -> [n_mel, dec_T]
            #print(spect.shape)
            melspec.append(spect)
        return torch.cat(melspec, dim=0)# [[n_mel, dec_T], ...] -> [n_stft*n_mel, dec_T]
    
    def __getitem__(self, audio_path):
        audio, sampling_rate, max_mag = load_wav_to_torch(audio_path) # load mono audio from file
        audio = audio / max_mag # normalize to range [-1, 1]
         
        spect = self.get_mel(audio)
        spect = dynamic_range_compression(spect)
        
        return spect

# %%
import iso226
import math
from CookieTTS.utils.model.utils import get_mask_from_lengths

# https://www.desmos.com/calculator/4nac7kvt7p
# Squash smaller values together so that mse loss is lower on quieter parts of the spectrogram.
def vol_rescale_loss(mel, power=0.5, min=-11.55):
    mel = mel + (power/(-min*2))*(mel**2)
    return mel


class LossFunction(nn.Module):
    def __init__(self, model_config):
        super(LossFunction, self).__init__()
        iso226_spl_from_freq = iso226.iso226_spl_itpl(L_N=60, hfe=True)# get InterpolatedUnivariateSpline for Perc Sound Pressure Level at Difference Frequencies with 60DB ref.
        self.freq_weights = torch.tensor([(2**(60./10))/(2**(iso226_spl_from_freq(freq)/10)) for freq in np.linspace(0, model_config['sampling_rate']//2, (model_config['filter_length']//2)+1)])
        self.freq_weights = self.freq_weights.repeat(len(model_config['window_lengths']))[None, :, None]# [B, n_mel, T]
        
        self.loud_loss_priority_str = model_config['loud_loss_priority']
    
    def forward(self, pred_spect, gt_spect):
        if self.loud_loss_priority_str > 0:
            pred_spect = vol_rescale_loss(pred_spect, power=self.loud_loss_priority_str)
            gt_spect = vol_rescale_loss(gt_spect, power=self.loud_loss_priority_str)
        
        MAE = F.mse_loss(pred_spect, gt_spect, reduction='none')
        MAE = MAE * self.freq_weights# [B, n_mel, T] * [1, n_mel, 1]
        
        return MAE.mean()

# %%
model_config = {
    'sampling_rate': 48000,
    'filter_length': 2400,
    'hop_length': 600,
    'window_lengths': [
        2400,
        1200,
    ],
    'loud_loss_priority': 0.0,
}

# %%
data_loader = AudioDataset(model_config)
criterion = LossFunction(model_config)

# %%
gt_path = r"G:\TwiBot\wavegrad\src\00_04_12_Twilight_Neutral__The first performance was so full of energy, so highly charged, That magical lightning showered down on the crowd.wav"
pred_paths = glob(r"G:\TwiBot\wavegrad\src\**\*.wav", recursive=True)

mean_best_vals = []
gt_spec = data_loader.__getitem__(gt_path)
for pred_path in pred_paths:
    pred_spec = data_loader.__getitem__(pred_path)
    min_length = min(pred_spec.shape[1], gt_spec.shape[1])
    pred_spec = pred_spec[:, :min_length]
    gt_spec = gt_spec[:, :min_length]
    MAE = criterion(pred_spec, gt_spec).item()
    print(f'{MAE:.3f} : {pred_path}')
    mean_best_vals.append(MAE)

model_perfs = {k: v for k, v in zip(pred_paths, mean_best_vals)}
sorted_model_perfs = {k: v for k, v in sorted(model_perfs.items(), key=lambda item: item[1])}
# Out:
# 0.000 : G:\TwiBot\wavegrad\src\00_04_12_Twilight_Neutral__The first performance was so full of energy, so highly charged, That magical lightning showered down on the crowd.wav
# 1.952 : G:\TwiBot\wavegrad\src\output-68736.wav
# 1.616 : G:\TwiBot\wavegrad\src\output-74464.wav
# 1.863 : G:\TwiBot\wavegrad\src\output-80192.wav
# 1.708 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_103086.wav
# 1.625 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_106904.wav
# 2.616 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_110722.wav
# 3.205 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_11454.wav
# 1.814 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_114540.wav
# 1.140 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_343620.wav
# 1.734 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_345529.wav
# 1.763 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_347438.wav
# 1.427 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_349347.wav
# 1.181 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_351256.wav
# 1.187 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_353165.wav
# 1.448 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_355074.wav
# 1.250 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_356983.wav
# 1.419 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_358892.wav
# 1.156 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_360801.wav
# 1.196 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_362710.wav
# 1.509 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_364619.wav
# 1.203 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_366528.wav
# 1.928 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_120736.wav
# 2.154 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_124509.wav
# 2.427 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_128282.wav
# 1.844 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_132055.wav
# 2.900 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_135828.wav
# 1.706 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_139601.wav
# 1.655 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_143374.wav
# 2.064 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_147147.wav
# 1.615 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_150920.wav
# 3.291 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_15272.wav
# 2.530 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_154693.wav
# 1.542 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_158466.wav
# 1.959 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_162239.wav
# 2.207 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_169785.wav
# 1.647 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_173558.wav
# 1.783 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_177331.wav
# 1.657 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_181104.wav
# 1.305 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_184877.wav
# 1.278 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_188650.wav
# 2.304 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_19090.wav
# 1.465 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_192423.wav
# 1.518 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_196196.wav
# 1.549 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_199969.wav
# 2.294 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_203742.wav
# 2.263 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_207515.wav
# 1.309 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_211288.wav
# 1.408 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_218834.wav
# 1.641 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_222607.wav
# 1.557 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_226380.wav
# 2.655 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_22908.wav
# 1.841 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_230153.wav
# 1.259 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_233926.wav
# 1.284 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_237699.wav
# 1.549 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_241472.wav
# 3.929 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_245245.wav
# 1.281 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_249018.wav
# 2.180 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_252791.wav
# 1.732 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_256564.wav
# 1.345 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_260337.wav
# 2.456 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_26726.wav
# 1.317 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_267883.wav
# 1.489 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_271656.wav
# 1.745 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_275429.wav
# 1.244 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_279202.wav
# 1.471 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_282975.wav
# 1.264 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_286748.wav
# 1.213 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_290521.wav
# 1.295 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_293986.wav
# 1.581 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_297804.wav
# 1.386 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_301622.wav
# 1.170 : G:\TwiBot\wavegrad\src\output_dist_fp16_3_303531.wav
# 2.024 : G:\TwiBot\wavegrad\src\output_dist_fp16_3
: G:\TwiBot\wavegrad\src\output_dist_fp16_5_503976.wav
# 1.508 : G:\TwiBot\wavegrad\src\output_dist_fp16_5_507794.wav
# 1.888 : G:\TwiBot\wavegrad\src\output_dist_fp16_5_511612.wav

# %%
print('\n'.join([f'{x[1]:.4f} | {x[0]:40}' for x in list(sorted_model_perfs.items())]))
# Out:
# 0.0000 | G:\TwiBot\wavegrad\src\00_04_12_Twilight_Neutral__The first performance was so full of energy, so highly charged, That magical lightning showered down on the crowd.wav
# 1.0236 | G:\TwiBot\wavegrad\src\output_dist_fp16_5_450524.wav
# 1.0815 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_423798.wav
# 1.0880 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_383709.wav
# 1.1022 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_372255.wav
# 1.1089 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_412344.wav
# 1.1165 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_377982.wav
# 1.1178 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_335984.wav
# 1.1219 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_404708.wav
# 1.1231 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_402799.wav
# 1.1241 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_370346.wav
# 1.1395 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_343620.wav
# 1.1411 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_334075.wav
# 1.1460 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_318803.wav
# 1.1493 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_330257.wav
# 1.1494 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_332166.wav
# 1.1497 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_341711.wav
# 1.1538 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_385618.wav
# 1.1556 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_360801.wav
# 1.1617 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_393254.wav
# 1.1692 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_414253.wav
# 1.1694 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_427616.wav
# 1.1702 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_303531.wav
# 1.1762 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_416162.wav
# 1.1810 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_351256.wav
# 1.1838 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_305440.wav
# 1.1873 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_353165.wav
# 1.1873 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_320712.wav
# 1.1899 | G:\TwiBot\wavegrad\src\output_dist_fp16_5_503976.wav
# 1.1963 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_362710.wav
# 1.2029 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_366528.wav
# 1.2050 | G:\TwiBot\wavegrad\src\output_dist_fp16_5_458160.wav
# 1.2134 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_290521.wav
# 1.2234 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_311167.wav
# 1.2267 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_316894.wav
# 1.2273 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_389436.wav
# 1.2322 | G:\TwiBot\wavegrad\src\output_dist_fp16_5_446706.wav
# 1.2444 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_279202.wav
# 1.2504 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_356983.wav
# 1.2592 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_233926.wav
# 1.2637 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_286748.wav
# 1.2659 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_326439.wav
# 1.2659 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_410435.wav
# 1.2776 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_188650.wav
# 1.2783 | G:\TwiBot\wavegrad\src\output_dist_fp16_5_461978.wav
# 1.2811 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_249018.wav
# 1.2830 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_322621.wav
# 1.2832 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_395163.wav
# 1.2836 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_237699.wav
# 1.2842 | G:\TwiBot\wavegrad\src\output_dist_fp16_5_488704.wav
# 1.2870 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_264110.wav
# 1.2888 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_368437.wav
# 1.2948 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_293986.wav
# 1.2970 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_376073.wav
# 1.2986 | G:\TwiBot\wavegrad\src\output_dist_fp16_5_465796.wav
# 1.3009 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_398981.wav
# 1.3049 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_184877.wav
# 1.3057 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_408526.wav
# 1.3087 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_211288.wav
# 1.3101 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_313076.wav
# 1.3165 | G:\TwiBot\wavegrad\src\output_dist_fp16_5_454342.wav
# 1.3167 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_267883.wav
# 1.3338 | G:\TwiBot\wavegrad\src\output_dist_fp16_5_473432.wav
# 1.3340 | G:\TwiBot\wavegrad\src\output_dist_fp16_5_484886.wav
# 1.3447 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_260337.wav
# 1.3509 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_339802.wav
# 1.3589 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_419980.wav
# 1.3801 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_166012.wav
# 1.3857 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_301622.wav
# 1.3884 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_381800.wav
# 1.3889 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_314985.wav
# 1.3978 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_397072.wav
# 1.4084 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_218834.wav
# 1.4188 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_358892.wav
# 1.4266 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_349347.wav
# 1.4292 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_387527.wav
# 1.4335 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_418071.wav
# 1.4476 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_355074.wav
# 1.4607 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_374164.wav
# 1.4611 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_337893.wav
# 1.4654 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_192423.wav
# 1.4666 | G:\TwiBot\wavegrad\src\output_dist_fp16_5_469614.wav
# 1.4709 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_282975.wav
# 1.4889 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_271656.wav
# 1.5080 | G:\TwiBot\wavegrad\src\output_dist_fp16_5_507794.wav
# 1.5086 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_364619.wav
# 1.5175 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_196196.wav
# 1.5424 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_158466.wav
# 1.5494 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_241472.wav
# 1.5495 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_199969.wav
# 1.5574 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_226380.wav
# 1.5754 | G:\TwiBot\wavegrad\src\output_dist_fp16_5_481068.wav
# 1.5812 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_297804.wav
# 1.5888 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_309258.wav
# 1.6153 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_150920.wav
# 1.6157 | G:\TwiBot\wavegrad\src\output-74464.wav
# 1.6246 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_106904.wav
# 1.6252 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_379891.wav
# 1.6289 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_215061.wav
# 1.6407 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_400890.wav
# 1.6410 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_222607.wav
# 1.6475 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_173558.wav
# 1.6543 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_87814.wav
# 1.6548 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_143374.wav
# 1.6562 | G:\TwiBot\wavegrad\src\output_dist_fp16_4_49634.wav
# 1.6570 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_181104.wav
# 1.6597 | G:\TwiBot\wavegrad\src\output_dist_fp16_4_57270.wav
# 1.6769 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_391345.wav
# 1.6911 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_328348.wav
# 1.6918 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_118358.wav
# 1.6951 | G:\TwiBot\wavegrad\src\output_dist_fp16_5_500158.wav
# 1.7026 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_68724.wav
# 1.7058 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_139601.wav
# 1.7076 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_103086.wav
# 1.7140 | G:\TwiBot\wavegrad\src\output_dist_fp16_5_492522.wav
# 1.7195 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_99268.wav
# 1.7317 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_256564.wav
# 1.7339 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_345529.wav
# 1.7445 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_275429.wav
# 1.7630 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_347438.wav
# 1.7717 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_83996.wav
# 1.7832 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_177331.wav
# 1.7883 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_421889.wav
# 1.8020 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_324530.wav
# 1.8139 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_114540.wav
# 1.8413 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_230153.wav
# 1.8438 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_132055.wav
# 1.8600 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_57270.wav
# 1.8633 | G:\TwiBot\wavegrad\src\output-80192.wav
# 1.8881 | G:\TwiBot\wavegrad\src\output_dist_fp16_5_511612.wav
# 1.9274 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_95450.wav
# 1.9279 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_120736.wav
# 1.9322 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_431434.wav
# 1.9521 | G:\TwiBot\wavegrad\src\output-68736.wav
# 1.9590 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_162239.wav
# 2.0127 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_435252.wav
# 2.0237 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_30544.wav
# 2.0347 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_53452.wav
# 2.0639 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_147147.wav
# 2.1391 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_307349.wav
# 2.1536 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_124509.wav
# 2.1713 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_41998.wav
# 2.1803 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_252791.wav
# 2.1969 | G:\TwiBot\wavegrad\src\output_dist_fp16_4_53452.wav
# 2.2019 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_61088.wav
# 2.2070 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_169785.wav
# 2.2578 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_76360.wav
# 2.2627 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_207515.wav
# 2.2941 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_203742.wav
# 2.3041 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_19090.wav
# 2.3494 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_406617.wav
# 2.4158 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_64906.wav
# 2.4274 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_128282.wav
# 2.4557 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_26726.wav
# 2.5195 | G:\TwiBot\wavegrad\src\output_dist_fp16_4_45816.wav
# 2.5303 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_154693.wav
# 2.5513 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_91632.wav
# 2.6159 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_110722.wav
# 2.6549 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_22908.wav
# 2.7402 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_34362.wav
# 2.7688 | G:\TwiBot\wavegrad\src\output_dist_fp16_5_496340.wav
# 2.8996 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_135828.wav
# 2.9492 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_72542.wav
# 3.0109 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_49634.wav
# 3.0841 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_7636.wav
# 3.2052 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_11454.wav
# 3.2372 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_80178.wav
# 3.2614 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_45816.wav
# 3.2905 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_15272.wav
# 3.7187 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_3818.wav
# 3.8649 | G:\TwiBot\wavegrad\src\output_dist_fp16_5_477250.wav
# 3.9295 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_245245.wav
# 4.8446 | G:\TwiBot\wavegrad\src\output_dist_fp16_3_38180.wav
# 16.8719 | G:\TwiBot\wavegrad\src\output_dist_fp16_5_442888.wav
