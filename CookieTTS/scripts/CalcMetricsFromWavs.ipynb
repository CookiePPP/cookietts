# %% [markdown]
# ## This notebook will search for WaveGlow/WaveFlow sample folders and calcuate metrics relating to audio quality for each folder.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import os
from glob import glob
from CookieTTS.utils.dataset.utils import load_wav_to_torch
from CookieTTS.utils.audio.stft import STFT
from CookieTTS.utils.audio.audio_processing import window_sumsquare, dynamic_range_compression, dynamic_range_decompression
# Out:
# D:\Miniconda\lib\site-packages\librosa\util\decorators.py:9: NumbaDeprecationWarning: An import was requested from a module that has moved location.
# Import requested from: 'numba.decorators', please update to use 'numba.core.decorators' or pin to Numba version 0.48.0. This alias will not be present in Numba version 0.50.0.
#   from numba.decorators import jit as optional_jit
# D:\Miniconda\lib\site-packages\librosa\util\decorators.py:9: NumbaDeprecationWarning: An import was requested from a module that has moved location.
# Import of 'jit' requested from: 'numba.decorators', please update to use 'numba.core.decorators' or pin to Numba version 0.48.0. This alias will not be present in Numba version 0.50.0.
#   from numba.decorators import jit as optional_jit

# %%
directory = r"H:\TTCheckpoints\wave_logdir_symlink"
list_of_samples_folders = [x[0] for x in os.walk(directory) if x[0].endswith('samples')]

# %%
model_names = [x.split('H:\\TTCheckpoints\\wave_logdir_symlink\\')[1].split('\\samples')[0].replace('\\','.') for x in list_of_samples_folders]

# %%
win_lens = [300]
hop_len = 65
fil_len = 2400
sampling_rate = 48000

stfts = []
for win_len in win_lens:
    stft = STFT(filter_length=fil_len,
                   hop_length=hop_len,
                   win_length=win_len,).cuda()
    stfts.append(stft)

# %%
def get_spect(audio):
    """Take audio and convert to multi-res spectrogram"""
    melspec = []
    for stft in stfts:
        spect = stft.transform(audio.unsqueeze(0), return_phase=False)[0].squeeze(0)# -> [n_mel, dec_T]
        #print(spect.shape)
        melspec.append(spect)
    return torch.cat(melspec, dim=0)# [[n_mel, dec_T], ...] -> [n_stft*n_mel, dec_T]

# %%
import numpy as np
import iso226
import math
iso226_spl_from_freq = iso226.iso226_spl_itpl(L_N=60, hfe=True)# get InterpolatedUnivariateSpline for Perc Sound Pressure Level at Difference Frequencies with 60DB ref.
freq_weights = torch.tensor([(2**(60./10))/(2**(iso226_spl_from_freq(freq)/10)) for freq in np.linspace(0, sampling_rate//2, (fil_len//2)+1)])
freq_weights = freq_weights.cuda().repeat(len(win_lens))[:, None]# [B, n_mel, T]

# %%
total_models = len(model_names)
mean_best_vals = []
for i, (model_name, sample_folder) in enumerate(zip(model_names, list_of_samples_folders)):
    print(f'{i:3}/{total_models:<} - {model_name}')
    gt_folder = os.path.join(sample_folder, 'Ground Truth')
    assert os.path.exists(gt_folder)
    pred_folders = [x[0] for x in os.walk(sample_folder) if not x[0] == gt_folder][1:]
    pred_folders = [x for x in pred_folders if '000-' in x]# allow only samples where the iter is a multiple of 1000
    
    best_vals = []
    gt_audio_files = glob(os.path.join(gt_folder, '*.wav'))
    len_gt_audio_files = len(gt_audio_files)
    gt_spects = {}
    for i, gt_audio_file in enumerate(gt_audio_files):
        #print(os.path.split(gt_audio_file)[-1], end='... ')
        best_vals.append(1e5)
        gt_audio, sr, max_mag = load_wav_to_torch(gt_audio_file)
        gt_audio = gt_audio.cuda()
        gt_audio /= max_mag
        gt_spect = get_spect(gt_audio)
        gt_spect = dynamic_range_compression(gt_spect, clip_val=1e-5)
        gt_spects[os.path.split(gt_audio_file)[-1]] = gt_spect
    
    best_mean_val = 1e9
    best_pred_folder = ''
    len_pred_folders = len(pred_folders)
    for i, pred_folder in enumerate(pred_folders):
        print(f'{i+1}/{len_pred_folders}', end='\r')
        vals = []
        for pred_audio_file in glob(os.path.join(pred_folder, '*.wav')):
            if os.path.split(pred_audio_file)[-1] in gt_spects.keys():
                gt_spect = gt_spects[os.path.split(pred_audio_file)[-1]]
                pred_audio, sr, max_mag = load_wav_to_torch(pred_audio_file)
                pred_audio = pred_audio.cuda()
                pred_audio = pred_audio[:gt_audio.shape[0]]
                pred_audio /= max_mag
                pred_spect = get_spect(pred_audio)
                pred_spect = dynamic_range_compression(pred_spect, clip_val=1e-5)
                min_length = min(gt_spect.shape[1], pred_spect.shape[1])
                pred_MAE = torch.nn.functional.l1_loss(pred_spect[:, :min_length], gt_spect[:, :min_length], reduction='none')
                pred_MAE *= freq_weights
                pred_MAE = pred_MAE.mean().item()
                vals.append(pred_MAE)
        if len(vals):
            mean_val = sum(vals)/len(vals)
            if mean_val < best_mean_val:
                best_mean_val = mean_val
                best_pred_folder = pred_folder
    print(f'{best_mean_val} | {os.path.split(best_pred_folder)[-1]}\n')
    mean_best_vals.append(best_mean_val)
# Out:
#   0/100 - waveflow.WaveGlow2.WaveGlow6
# 0.43790902694066364 | 253000-2020_07_28-01_02_36
#
#   1/100 - waveflow.WaveGlow2.WaveGlow5
# 0.4314320385456085 | 263000-2020_07_28-10_36_34
#
#   2/100 - waveflow.WaveGlow2
# 0.45375850134425694 | 206000-2020_07_24-19_47_44
#
#   3/100 - waveflow.WaveGlow2.WaveGlow4
# 0.5140067769421471 | 213000-2020_07_25-02_38_20
#
#   4/100 - waveflow.WaveGlow2.WaveGlow3
# 0.46576651599672103 | 213000-2020_07_25-00_49_04
#
#   5/100 - waveflow.WaveGlow.50G12F256C
# 0.7245897650718689 | 896000-2020_06_28-22_21_26
#
#   6/100 - waveflow.WaveGlow
# 0.43754787955965313 | 368000-2020_07_16-14_42_31
#
#   7/100 - waveflow.6thARSmall.with_res_skip
# 0.42919816289629253 | 810000-2020_06_22-17_55_11
#
#   8/100 - waveflow.6thARSmall.with_res_skip_and_separable
# 0.4378726141793387 | 886000-2020_06_23-00_45_01
#
#   9/100 - waveflow.6thARSmall
# 0.4263772964477539 | 992000-2020_06_24-11_44_29
#
#  10/100 - waveflow.6thARSmall.without_res_skip
# 0.4458443011556353 | 840000-2020_06_22-08_54_50
#
#  11/100 - waveflow.3rdLargeKernels
# 0.524387504373278 | 303000-2020_06_13-10_48_53
#
#  12/100 - waveflow.4thLargeKernels.AR_8_Flow_AEF3
# 0.5627010299099816 | 13000-2020_09_05-21_27_37
#
#  13/100 - waveflow.4thLargeKernels.AR_8_Flow
# 0.4705325861771901 | 43000-2020_08_18-20_30_06
#
#  14/100 - waveflow.4thLargeKernels.AR_8_Flow.gt3
# 0.3893564111656613 | 1330000-2020_08_04-17_41_56
#
#  15/100 - waveflow.4thLargeKernels.AR_8_Flow_AEF4
# 0.37610593769285416 | 479000-2020_09_12-05_49_57
#
#  16/100 - waveflow.4thLargeKernels.AR_10_Flow_wip
# 0.4150842343057905 | 624000-2020_06_18-08_27_31
#
#  17/100 - waveflow.4thLargeKernels.WG_24_Flow_AEF4.1
# 0.37962885366545784 | 5000-2020_10_01-01_43_46
#
#  18/100 - waveflow.4thLargeKernels.GTRU_12Flow
# 0.42453530099656844 | 39000-2020_08_10-12_22_27
#
#  19/100 - waveflow.4thLargeKernels.AR_8_Flow_AEF4.1
# 0.3549918598598904 | 247000-2020_09_17-14_27_50
#
#  20/100 - waveflow.4thLargeKernels.AR_8_Flow_AEF4.1.1_nonsep
# 0.36335763335227966 | 94000-2020_09_28-03_30_30
#
#  21/100 - waveflow.4thLargeKernels.AR_6_Flow
# 0.4077959273542677 | 600000-2020_06_18-03_13_47
#
#  22/100 - waveflow.4thLargeKernels.AR_6_Flow_512C
# 0.40068464619772776 | 784000-2020_06_25-04_00_17
#
#  23/100 - waveflow.4thLargeKernels.GSIRRU
# 0.436333782143063 | 69000-2020_08_09-18_33_49
#
#  24/100 - waveflow.4thLargeKernels.GSIU
# 0.4464932514561547 | 47000-2020_08_09-09_27_07
#
#  25/100 - waveflow.4thLargeKernels.AR_8_Flow_256C_HDN
# 0.4235950509707133 | 260000-2020_09_01-23_53_34
#
#  26/100 - waveflow.4thLargeKernels.GSIRU
# 0.42916738655832076 | 100000-2020_08_09-18_34_37
#
#  27/100 - waveflow.4thLargeKernels.GSIRU_384C_4Flow
# 0.39285298850801254 | 297000-2020_08_13-05_40_19
#
#  28/100 - waveflow.4thLargeKernels.AR_8_Flow_AEF2
# 0.37432000372144913 | 13000-2020_09_06-05_45_24
#
#  29/100 - waveflow.4thLargeKernels.AR_8_Flow_HDN
# 0.42869557605849373 | 105000-2020_08_30-07_12_33
#
#  30/100 - waveflow.4thLargeKernels.GSIRRU_16_Flow
# 0.44450221127933925 | 53000-2020_08_11-09_16_37
#
#  31/100 - waveflow.4thLargeKernels.GTRU_256C
# 1.238731602827708 | 3000-2020_08_09-22_18_14
#
#  32/100 - waveflow.4thLargeKernels.AR_10_Flow.prec_vol_scaling
# 0.6023564802275764 | 2000-2020_08_11-04_11_08
#
#  33/100 - waveflow.4thLargeKernels.AR_10_Flow
# 0.4798655046357049 | 241000-2020_08_18-04_45_07
#
#  34/100 - waveflow.4thLargeKernels.AR_8_Flow_AEF4.2_iso226
# 0.42084989613956875 | 92000-2020_09_15-04_59_37
#
#  35/100 - waveflow.4thLargeKernels.WG_12_Flow_AEF4.1
# 0.37373805046081543 | 100000-2020_09_30-13_15_59
#
#  36/100 - waveflow.4thLargeKernels.empthasis_AR_6_Flow_512C
# 0.38585440601621357 | 874000-2020_06_27-06_22_31
#
#  37/100 - waveflow.4thLargeKernels.AR_6_Flow_512C_ssvae2_2
# 0.4310915271441142 | 85000-2020_08_28-16_38_10
#
#  38/100 - waveflow.4thLargeKernels.empthasis_AR_8F_512C
# 0.45403570788247244 | 939000-2020_06_30-20_47_56
#
#  39/100 - waveflow.4thLargeKernels.GLU
# 0.4800327817598979 | 16000-2020_08_09-05_18_39
#
#  40/100 - waveflow.4thLargeKernels.GTLRU_8_Flow
# 0.501546217335595 | 12000-2020_08_17-02_28_12
#
#  41/100 - waveflow.4thLargeKernels.perceived_vol_AR_6F_512C
# 0.4239643727030073 | 782000-2020_06_24-20_22_48
#
#  42/100 - waveflow.4thLargeKernels.TTU_with_grad_clipping
# 0.4345317516061995 | 61000-2020_08_10-03_43_05
#
#  43/100 - waveflow.4thLargeKernels.GTRU_6Flow_256C
# 1000000000.0 |
#
#  44/100 - waveflow.4thLargeKernels.AR_8_Flow_AEF
# 0.3591603702969021 | 242000-2020_09_07-21_14_29
#
#  45/100 - waveflow.4thLargeKernels.GTU
# 0.452935129404068 | 47000-2020_08_09-08_10_43
#
#  46/100 - waveflow.4thLargeKernels.GTSU
# 0.45881175332599217 | 38000-2020_08_09-11_47_21
#
#  47/100 - waveflow.4thLargeKernels.GTRU
# 0.4395602014329698 | 64000-2020_08_09-09_35_56
#
#  48/100 - waveflow.4thLargeKernels.AR_8_Flow_DTW2
# 0.41372783647643196 | 71000-2020_08_29-02_07_18
#
#  49/100 - waveflow.4thLargeKernels.SPTU
# 0.4357788960138957 | 103000-2020_08_09-18_24_05
#
#  50/100 - waveflow.4thLargeKernels.AR_8_Flow_24Khz_Fmax
# 0.3853098452091217 | 210000-2020_08_09-00_02_16
#
#  51/100 - waveflow.4thLargeKernels.AR_8_Flow_24Khz_Fmax.TooLargeModel
# 0.41370441847377354 | 1486000-2020_08_07-22_53_32
#
#  52/100 - waveflow.4thLargeKernels.AR_6_Flow_512C_ssvae2
# 0.43451930085817975 | 119000-2020_08_27-21_26_41
#
#  53/100 - waveflow.4thLargeKernels.bipart_coupling.saved
# 0.8801070366586957 | 333000-2020_06_15-08_36_00
#
#  54/100 - waveflow.4thLargeKernels.bipart_coupling.causal_padding
# 0.7521162969725472 | 333000-2020_06_14-11_02_22
#
#  55/100 - waveflow.4thLargeKernels.bipart_coupling.non_causal_padding
# 0.6322204981531415 | 354000-2020_06_14-08_07_08
#
#  56/100 - waveflow.4thLargeKernels.bipart_coupling.const_dilation_factor
# 0.6799125586237226 | 390000-2020_06_13-23_30_00
#
#  57/100 - waveflow.7thHeightDilated
# 0.40995554413114277 | 921000-2020_06_28-21_06_13
#
#  58/100 - waveflow.7thHeightDilated.32C12F
# 0.38874744517462595 | 1084000-2020_06_28-14_47_31
#
#  59/100 - waveflow.Baseline
# 0.5930428658762286 | 115000-2020_06_11-00_04_37
#
#  60/100 - waveflow.Baseline.1st
# 1.461489777411184 | 75000-2020_06_10-11_41_58
#
#  61/100 - waveflow.2ndRevision.1x1conv_samples
# 0.5239644110202789 | 224000-2020_06_12-08_06_34
#
#  62/100 - waveflow.2ndRevision
# 0.5374822199344635 | 272000-2020_06_12-19_21_42
#
#  63/100 - waveflow.5thBaseline
# 0.455347125019346 | 368000-2020_06_14-23_59_04
#
#  64/100 - waveflow.FixedBaseline
# 0.4458511344024113 | 16000-2020_06_15-07_11_29
#
#  65/100 - waveflow.FixedBaseline.6_Flow
# 0.7574653114591327 | 4000-2020_06_15-02_19_16
#
#  66/100 - waveglow.outdir_EfficientLarge3.5.Postnetax
# 0.49458281153982336 | 213000-2020_06_02-11_03_14
#
#  67/100 - waveglow.outdir_EfficientLarge3.5
# 0.45689558833837507 | 190000-2020_05_17-22_21_37
#
#  68/100 - waveglow.outdir_EfficientLarge3.5.Postnet
# 0.47767725451426074 | 196000-2020_05_26-09_18_18
#
#  69/100 - waveglow.outdir_EfficientLarge3.5.Postnetax2
# 0.4567391669208353 | 203000-2020_06_05-18_17_03
#
#  70/100 - waveglow.outdir_NancyOnly
# 0.4718562936782837 | 75000-2020_03_30-22_44_51
#
#  71/100 - waveglow.outdir_EfficientLarge5
# 0.4129628562927246 | 42000-2020_05_05-03_34_43
#
#  72/100 - waveglow.outdir_EfficientSmall
# 0.41006635546684267 | 68000-2020_04_15-02_58_50
#
#  73/100 - waveglow.outdir_EfficientLarge2
# 0.5305113136768341 | 16000-2020_04_05-14_23_03
#
#  74/100 - waveglow.outdir_EfficientSmallGlobalSpeakerEmbeddings_SmallWindow
# 0.4893384802341461 | 26000-2020_04_28-00_12_54
#
#  75/100 - waveglow.outdir_EfficientSmallGlobalSpeakerEmbeddings_SmallWindow.orig
# 0.46623024821281434 | 11000-2020_04_27-18_58_51
#
#  76/100 - waveglow.outdir_EfficientLarge4
# 0.40070111393928526 | 110000-2020_05_02-15_06_18
#
#  77/100 - waveglow.outdir_EfficientLarge5.1
# 0.4298283696174622 | 72000-2020_05_08-01_57_50
#
#  78/100 - waveglow.outdir_EfficientLarge4.1
# 0.42305312395095823 | 79000-2020_05_01-01_00_08
#
#  79/100 - waveglow.outdir_MultispeakerStackedConvs
# 0.4239885592460632 | 101000-2020_04_27-14_52_03
#
#  80/100 - waveglow.outdir_verylargeGroup
# 0.7958688592910766 | 18000-2020_04_04-10_04_32
#
#  81/100 - waveglow.outdir_smallGroup
# 1000000000.0 |
#
#  82/100 - waveglow.outdir_EfficientLarge6
# 0.482792682117886 | 56000-2020_09_15-23_18_23
#
#  83/100 - waveglow.outdir_MultispeakerBaseline
# 0.43207633852958677 | 60000-2020_04_20-05_36_56
#
#  84/100 - waveglow.outdir_EfficientLarge
# 0.4056981635093689 | 274000-2020_04_10-11_45_37
#
#  85/100 - waveglow.outdir_largeGroup_ReZero
# 1.5522965788841248 | 2000-2020_04_08-14_57_54
#
#  86/100 - waveglow.outdir_EfficientLarge3
# 0.42070993423461917 | 90000-2020_04_13-01_52_28
#
#  87/100 - waveglow.outdir_EfficientSmallGlobalSpeakerEmbeddings.12-layer_2-n_group
# 1.408405483814708 | 1000-2020_05_18-00_05_54
#
#  88/100 - waveglow.outdir_EfficientSmallGlobalSpeakerEmbeddings.Testing2
# 0.4329892708496614 | 283000-2020_05_23-15_03_23
#
#  89/100 - waveglow.outdir_EfficientSmallGlobalSpeakerEmbeddings.Aligncorners_Testing.aligncorners_OFF
# 1000000000.0 |
#
#  90/100 - waveglow.outdir_EfficientSmallGlobalSpeakerEmbeddings.Aligncorners_Testing.aligncorners_ON
# 1000000000.0 |
#
#  91/100 - waveglow.outdir_EfficientSmallGlobalSpeakerEmbeddings.extreme_n_channels
# 0.5435806790536101 | 8000-2020_06_04-10_27_44
#
#  92/100 - waveglow.outdir_EfficientSmallGlobalSpeakerEmbeddings.Testing
# 0.3997115409374237 | 106000-2020_05_06-20_41_06
#
#  93/100 - waveglow.outdir_EfficientSmallGlobalSpeakerEmbeddings.Testing2.1
# 0.38246341824531555 | 279000-2020_05_11-09_06_19
#
#  94/100 - waveglow.outdir_EfficientSmallGlobalSpeakerEmbeddings
# 0.3881417119503021 | 131000-2020_04_21-07_32_34
#
#  95/100 - waveglow.outdir_EfficientSmallGlobalSpeakerEmbeddings.Testing3
# 0.6178954303264618 | 160000-2020_05_07-11_26_36
#
#  96/100 - waveglow.outdir_EfficientSmallGlobalSpeakerEmbeddings.Testing2.2
# 0.4122721776366234 | 70000-2020_06_07-17_30_12
#
#  97/100 - waveglow.outdir_EfficientSmallGlobalSpeakerEmbeddings.6_Flow
# 0.4550336626442996 | 390000-2020_05_25-11_09_24
#
#  98/100 - waveglow.outdir_largeGroup
# 0.45795172452926636 | 60000-2020_04_03-12_21_05
#
#  99/100 - waveglow.outdir_EfficientSmallSpeakerEmbeddings
# 0.4012070345878601 | 94000-2020_04_14-15_54_00

# %%
mean_best_vals = [float(x) if not 'N/A' in str(x) else 1e5 for x in mean_best_vals]
model_perfs = {k: v for k, v in zip(model_names, mean_best_vals)}
sorted_model_perfs = {k: v for k, v in sorted(model_perfs.items(), key=lambda item: item[1])}

# %%
# val MAE with [300] windows
print('\n'.join([f'{x[1]:.4f} | {x[0]:40}' for x in list(sorted_model_perfs.items())]))
# Out:
# 0.3550 | waveflow.4thLargeKernels.AR_8_Flow_AEF4.1
# 0.3592 | waveflow.4thLargeKernels.AR_8_Flow_AEF
# 0.3634 | waveflow.4thLargeKernels.AR_8_Flow_AEF4.1.1_nonsep
# 0.3737 | waveflow.4thLargeKernels.WG_12_Flow_AEF4.1
# 0.3743 | waveflow.4thLargeKernels.AR_8_Flow_AEF2
# 0.3761 | waveflow.4thLargeKernels.AR_8_Flow_AEF4
# 0.3796 | waveflow.4thLargeKernels.WG_24_Flow_AEF4.1
# 0.3825 | waveglow.outdir_EfficientSmallGlobalSpeakerEmbeddings.Testing2.1
# 0.3853 | waveflow.4thLargeKernels.AR_8_Flow_24Khz_Fmax
# 0.3859 | waveflow.4thLargeKernels.empthasis_AR_6_Flow_512C
# 0.3881 | waveglow.outdir_EfficientSmallGlobalSpeakerEmbeddings
# 0.3887 | waveflow.7thHeightDilated.32C12F
# 0.3894 | waveflow.4thLargeKernels.AR_8_Flow.gt3
# 0.3929 | waveflow.4thLargeKernels.GSIRU_384C_4Flow
# 0.3997 | waveglow.outdir_EfficientSmallGlobalSpeakerEmbeddings.Testing
# 0.4007 | waveflow.4thLargeKernels.AR_6_Flow_512C
# 0.4007 | waveglow.outdir_EfficientLarge4
# 0.4012 | waveglow.outdir_EfficientSmallSpeakerEmbeddings
# 0.4057 | waveglow.outdir_EfficientLarge
# 0.4078 | waveflow.4thLargeKernels.AR_6_Flow
# 0.4100 | waveflow.7thHeightDilated
# 0.4101 | waveglow.outdir_EfficientSmall
# 0.4123 | waveglow.outdir_EfficientSmallGlobalSpeakerEmbeddings.Testing2.2
# 0.4130 | waveglow.outdir_EfficientLarge5
# 0.4137 | waveflow.4thLargeKernels.AR_8_Flow_24Khz_Fmax.TooLargeModel
# 0.4137 | waveflow.4thLargeKernels.AR_8_Flow_DTW2
# 0.4151 | waveflow.4thLargeKernels.AR_10_Flow_wip
# 0.4207 | waveglow.outdir_EfficientLarge3
# 0.4208 | waveflow.4thLargeKernels.AR_8_Flow_AEF4.2_iso226
# 0.4231 | waveglow.outdir_EfficientLarge4.1
# 0.4236 | waveflow.4thLargeKernels.AR_8_Flow_256C_HDN
# 0.4240 | waveflow.4thLargeKernels.perceived_vol_AR_6F_512C
# 0.4240 | waveglow.outdir_MultispeakerStackedConvs
# 0.4245 | waveflow.4thLargeKernels.GTRU_12Flow
# 0.4264 | waveflow.6thARSmall
# 0.4287 | waveflow.4thLargeKernels.AR_8_Flow_HDN
# 0.4292 | waveflow.4thLargeKernels.GSIRU
# 0.4292 | waveflow.6thARSmall.with_res_skip
# 0.4298 | waveglow.outdir_EfficientLarge5.1
# 0.4311 | waveflow.4thLargeKernels.AR_6_Flow_512C_ssvae2_2
# 0.4314 | waveflow.WaveGlow2.WaveGlow5
# 0.4321 | waveglow.outdir_MultispeakerBaseline
# 0.4330 | waveglow.outdir_EfficientSmallGlobalSpeakerEmbeddings.Testing2
# 0.4345 | waveflow.4thLargeKernels.AR_6_Flow_512C_ssvae2
# 0.4345 | waveflow.4thLargeKernels.TTU_with_grad_clipping
# 0.4358 | waveflow.4thLargeKernels.SPTU
# 0.4363 | waveflow.4thLargeKernels.GSIRRU
# 0.4375 | waveflow.WaveGlow
# 0.4379 | waveflow.6thARSmall.with_res_skip_and_separable
# 0.4379 | waveflow.WaveGlow2.WaveGlow6
# 0.4396 | waveflow.4thLargeKernels.GTRU
# 0.4445 | waveflow.4thLargeKernels.GSIRRU_16_Flow
# 0.4458 | waveflow.6thARSmall.without_res_skip
# 0.4459 | waveflow.FixedBaseline
# 0.4465 | waveflow.4thLargeKernels.GSIU
# 0.4529 | waveflow.4thLargeKernels.GTU
# 0.4538 | waveflow.WaveGlow2
# 0.4540 | waveflow.4thLargeKernels.empthasis_AR_8F_512C
# 0.4550 | waveglow.outdir_EfficientSmallGlobalSpeakerEmbeddings.6_Flow
# 0.4553 | waveflow.5thBaseline
# 0.4567 | waveglow.outdir_EfficientLarge3.5.Postnetax2
# 0.4569 | waveglow.outdir_EfficientLarge3.5
# 0.4580 | waveglow.outdir_largeGroup
# 0.4588 | waveflow.4thLargeKernels.GTSU
# 0.4658 | waveflow.WaveGlow2.WaveGlow3
# 0.4662 | waveglow.outdir_EfficientSmallGlobalSpeakerEmbeddings_SmallWindow.orig
# 0.4705 | waveflow.4thLargeKernels.AR_8_Flow
# 0.4719 | waveglow.outdir_NancyOnly
# 0.4777 | waveglow.outdir_EfficientLarge3.5.Postnet
# 0.4799 | waveflow.4thLargeKernels.AR_10_Flow
# 0.4800 | waveflow.4thLargeKernels.GLU
# 0.4828 | waveglow.outdir_EfficientLarge6
# 0.4893 | waveglow.outdir_EfficientSmallGlobalSpeakerEmbeddings_SmallWindow
# 0.4946 | waveglow.outdir_EfficientLarge3.5.Postnetax
# 0.5015 | waveflow.4thLargeKernels.GTLRU_8_Flow
# 0.5140 | waveflow.WaveGlow2.WaveGlow4
# 0.5240 | waveflow.2ndRevision.1x1conv_samples
# 0.5244 | waveflow.3rdLargeKernels
# 0.5305 | waveglow.outdir_EfficientLarge2
# 0.5375 | waveflow.2ndRevision
# 0.5436 | waveglow.outdir_EfficientSmallGlobalSpeakerEmbeddings.extreme_n_channels
# 0.5627 | waveflow.4thLargeKernels.AR_8_Flow_AEF3
# 0.5930 | waveflow.Baseline
# 0.6024 | waveflow.4thLargeKernels.AR_10_Flow.prec_vol_scaling
# 0.6179 | waveglow.outdir_EfficientSmallGlobalSpeakerEmbeddings.Testing3
# 0.6322 | waveflow.4thLargeKernels.bipart_coupling.non_causal_padding
# 0.6799 | waveflow.4thLargeKernels.bipart_coupling.const_dilation_factor
# 0.7246 | waveflow.WaveGlow.50G12F256C
# 0.7521 | waveflow.4thLargeKernels.bipart_coupling.causal_padding
# 0.7575 | waveflow.FixedBaseline.6_Flow
# 0.7959 | waveglow.outdir_verylargeGroup
# 0.8801 | waveflow.4thLargeKernels.bipart_coupling.saved
# 1.2387 | waveflow.4thLargeKernels.GTRU_256C
# 1.4084 | waveglow.outdir_EfficientSmallGlobalSpeakerEmbeddings.12-layer_2-n_group
# 1.4615 | waveflow.Baseline.1st
# 1.5523 | waveglow.outdir_largeGroup_ReZero
# 1000000000.0000 | waveflow.4thLargeKernels.GTRU_6Flow_256C
# 1000000000.0000 | waveglow.outdir_smallGroup
# 1000000000.0000 | waveglow.outdir_EfficientSmallGlobalSpeakerEmbeddings.Aligncorners_Testing.aligncorners_OFF
# 1000000000.0000 | waveglow.outdir_EfficientSmallGlobalSpeakerEmbeddings.Aligncorners_Testing.aligncorners_ON

# %%
# val MAE with [600, 1200] windows
print('\n'.join([f'{x[1]:.4f} | {x[0]:40}' for x in list(sorted_model_perfs.items())]))
# Out:
# 0.3470 | waveflow.4thLargeKernels.AR_8_Flow_AEF4.1
# 0.3521 | waveflow.4thLargeKernels.AR_8_Flow_AEF
# 0.3570 | waveflow.4thLargeKernels.AR_8_Flow_AEF4.1.1_nonsep
# 0.3700 | waveflow.4thLargeKernels.AR_8_Flow_AEF2
# 0.3714 | waveflow.4thLargeKernels.AR_8_Flow.gt3
# 0.3717 | waveglow.outdir_EfficientSmallGlobalSpeakerEmbeddings.Testing2.1
# 0.3742 | waveflow.4thLargeKernels.empthasis_AR_6_Flow_512C
# 0.3753 | waveflow.4thLargeKernels.AR_8_Flow_24Khz_Fmax
# 0.3770 | waveflow.4thLargeKernels.WG_12_Flow_AEF4.1
# 0.3798 | waveflow.4thLargeKernels.AR_8_Flow_AEF4
# 0.3816 | waveflow.7thHeightDilated.32C12F
# 0.3850 | waveglow.outdir_EfficientSmallGlobalSpeakerEmbeddings
# 0.3896 | waveflow.4thLargeKernels.GSIRU_384C_4Flow
# 0.3896 | waveflow.4thLargeKernels.AR_6_Flow_512C
# 0.3904 | waveglow.outdir_EfficientLarge4
# 0.3977 | waveglow.outdir_EfficientSmallGlobalSpeakerEmbeddings.Testing
# 0.3978 | waveglow.outdir_EfficientLarge
# 0.3990 | waveflow.4thLargeKernels.AR_6_Flow
# 0.4018 | waveglow.outdir_EfficientSmallGlobalSpeakerEmbeddings.Testing2.2
# 0.4033 | waveflow.4thLargeKernels.AR_10_Flow_wip
# 0.4057 | waveglow.outdir_EfficientSmallSpeakerEmbeddings
# 0.4085 | waveflow.7thHeightDilated
# 0.4100 | waveflow.4thLargeKernels.AR_8_Flow_DTW2
# 0.4113 | waveflow.4thLargeKernels.AR_8_Flow_AEF4.2_iso226
# 0.4116 | waveglow.outdir_EfficientLarge4.1
# 0.4118 | waveflow.4thLargeKernels.AR_8_Flow_24Khz_Fmax.TooLargeModel
# 0.4122 | waveglow.outdir_EfficientLarge3
# 0.4138 | waveflow.4thLargeKernels.AR_6_Flow_512C_ssvae2_2
# 0.4153 | waveglow.outdir_MultispeakerStackedConvs
# 0.4163 | waveglow.outdir_EfficientSmallGlobalSpeakerEmbeddings.Testing2
# 0.4165 | waveglow.outdir_EfficientLarge5
# 0.4166 | waveflow.4thLargeKernels.AR_6_Flow_512C_ssvae2
# 0.4195 | waveflow.4thLargeKernels.perceived_vol_AR_6F_512C
# 0.4205 | waveglow.outdir_EfficientSmall
# 0.4220 | waveflow.4thLargeKernels.GTRU_12Flow
# 0.4231 | waveflow.4thLargeKernels.AR_8_Flow_256C_HDN
# 0.4233 | waveflow.WaveGlow2.WaveGlow5
# 0.4253 | waveflow.4thLargeKernels.AR_8_Flow_HDN
# 0.4299 | waveflow.WaveGlow2.WaveGlow6
# 0.4325 | waveglow.outdir_EfficientLarge3.5
# 0.4329 | waveflow.4thLargeKernels.GSIRRU_16_Flow
# 0.4342 | waveflow.WaveGlow
# 0.4350 | waveglow.outdir_MultispeakerBaseline
# 0.4356 | waveglow.outdir_EfficientLarge5.1
# 0.4367 | waveflow.6thARSmall
# 0.4394 | waveflow.6thARSmall.with_res_skip
# 0.4401 | waveglow.outdir_EfficientLarge3.5.Postnetax2
# 0.4411 | waveflow.4thLargeKernels.GSIRU
# 0.4420 | waveflow.4thLargeKernels.TTU_with_grad_clipping
# 0.4428 | waveflow.WaveGlow2
# 0.4441 | waveglow.outdir_EfficientSmallGlobalSpeakerEmbeddings.6_Flow
# 0.4458 | waveflow.4thLargeKernels.GSIRRU
# 0.4482 | waveflow.4thLargeKernels.GTRU
# 0.4528 | waveflow.4thLargeKernels.AR_8_Flow
# 0.4535 | waveflow.4thLargeKernels.SPTU
# 0.4563 | waveflow.4thLargeKernels.AR_10_Flow
# 0.4568 | waveflow.6thARSmall.with_res_skip_and_separable
# 0.4579 | waveflow.6thARSmall.without_res_skip
# 0.4587 | waveglow.outdir_EfficientLarge3.5.Postnet
# 0.4598 | waveglow.outdir_largeGroup
# 0.4629 | waveflow.4thLargeKernels.GSIU
# 0.4685 | waveflow.4thLargeKernels.GTU
# 0.4714 | waveflow.4thLargeKernels.empthasis_AR_8F_512C
# 0.4714 | waveflow.FixedBaseline
# 0.4725 | waveglow.outdir_NancyOnly
# 0.4746 | waveflow.4thLargeKernels.GTSU
# 0.4759 | waveglow.outdir_EfficientLarge3.5.Postnetax
# 0.4822 | waveflow.5thBaseline
# 0.4828 | waveflow.WaveGlow2.WaveGlow3
# 0.4830 | waveglow.outdir_EfficientSmallGlobalSpeakerEmbeddings_SmallWindow.orig
# 0.4934 | waveglow.outdir_EfficientSmallGlobalSpeakerEmbeddings_SmallWindow
# 0.4943 | waveflow.4thLargeKernels.GTLRU_8_Flow
# 0.4963 | waveglow.outdir_EfficientLarge6
# 0.4994 | waveflow.4thLargeKernels.GLU
# 0.5205 | waveflow.2ndRevision.1x1conv_samples
# 0.5327 | waveglow.outdir_EfficientLarge2
# 0.5377 | waveflow.WaveGlow2.WaveGlow4
# 0.5379 | waveflow.2ndRevision
# 0.5432 | waveglow.outdir_EfficientSmallGlobalSpeakerEmbeddings.extreme_n_channels
# 0.5566 | waveflow.3rdLargeKernels
# 0.5574 | waveflow.4thLargeKernels.AR_8_Flow_AEF3
# 0.5926 | waveflow.Baseline
# 0.6300 | waveflow.4thLargeKernels.AR_10_Flow.prec_vol_scaling
# 0.6512 | waveglow.outdir_EfficientSmallGlobalSpeakerEmbeddings.Testing3
# 0.6623 | waveflow.4thLargeKernels.bipart_coupling.non_causal_padding
# 0.7082 | waveflow.4thLargeKernels.bipart_coupling.const_dilation_factor
# 0.7492 | waveflow.WaveGlow.50G12F256C
# 0.7840 | waveflow.4thLargeKernels.bipart_coupling.causal_padding
# 0.7931 | waveflow.FixedBaseline.6_Flow
# 0.8266 | waveglow.outdir_verylargeGroup
# 0.9087 | waveflow.4thLargeKernels.bipart_coupling.saved
# 1.2912 | waveflow.4thLargeKernels.GTRU_256C
# 1.4007 | waveglow.outdir_EfficientSmallGlobalSpeakerEmbeddings.12-layer_2-n_group
# 1.4602 | waveflow.Baseline.1st
# 1.5909 | waveglow.outdir_largeGroup_ReZero
# 1000000000.0000 | waveflow.4thLargeKernels.GTRU_6Flow_256C
# 1000000000.0000 | waveglow.outdir_smallGroup
# 1000000000.0000 | waveglow.outdir_EfficientSmallGlobalSpeakerEmbeddings.Aligncorners_Testing.aligncorners_OFF
# 1000000000.0000 | waveglow.outdir_EfficientSmallGlobalSpeakerEmbeddings.Aligncorners_Testing.aligncorners_ON

# %%
# val MAE with [300, 600, 1200, 2400] windows
print('\n'.join([f'{x[1]:.4f} | {x[0]:40}' for x in list(sorted_model_perfs.items())]))
