# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import os
import random

# %%
from typing import List

def create_binary_list_from_int(number: int) -> List[int]:
    if number < 0 or type(number) is not int:
        raise ValueError("Only Positive integers are allowed")

    return [int(x) for x in list(bin(number))[2:]]

# %%
def generate_even_data(max_int: int, batch_size: int=16):
    # Get the number of binary places needed to represent the maximum number
    max_length = int(math.log(max_int, 2))

    # Sample batch_size number of integers in range 0-max_int
    sampled_integers = np.random.randint(0, int(max_int / 2), batch_size)

    # create a list of labels all ones because all numbers are even
    labels = [1] * batch_size

    # Generate a list of binary numbers for training.
    data = [create_binary_list_from_int(int(x * 2)) for x in sampled_integers]
    data = [([0] * (max_length - len(x))) + x for x in data]

    return labels, data

# %%
class Generator(nn.Module):

    def __init__(self, input_length: int):
        super(Generator, self).__init__()
        self.dense_layer = nn.Linear(int(input_length), int(input_length))
        self.activation = nn.Sigmoid()

    def forward(self, x):
        return self.activation(self.dense_layer(x))

# %%
class Discriminator(nn.Module):
    def __init__(self, input_length: int):
        super(Discriminator, self).__init__()
        self.dense = nn.Linear(int(input_length), 1);
        self.activation = nn.Sigmoid()

    def forward(self, x):
        return self.activation(self.dense(x))

# %%
import math

import torch
import torch.nn as nn


def train(max_int: int = 128, batch_size: int = 16, training_steps: int = 500):
    input_length = int(math.log(max_int, 2))
    
    # Models
    generator = Generator(input_length)
    discriminator = Discriminator(input_length)
    
    # Optimizers
    generator_optimizer = torch.optim.Adam(generator.parameters(), lr=0.001)
    discriminator_optimizer = torch.optim.Adam(discriminator.parameters(), lr=0.001)
    
    # loss
    loss = nn.BCELoss()
    
    for i in range(training_steps):
        # zero the gradients on each iteration
        generator_optimizer.zero_grad()
        
        # Create noisy input for generator
        # Need float type instead of int
        noise = torch.randint(0, 2, size=(batch_size, input_length)).float()
        generated_data = generator(noise)
        
        # Generate examples of even real data
        true_labels, true_data = generate_even_data(max_int, batch_size=batch_size)
        true_labels = torch.tensor(true_labels).float()
        true_data = torch.tensor(true_data).float()
        
        # Train the generator
        # We invert the labels here and don't train the discriminator because we want the generator
        # to make things the discriminator classifies as true.
        generator_discriminator_out = discriminator(generated_data)
        generator_loss = loss(generator_discriminator_out, true_labels)
        generator_loss.backward()
        generator_optimizer.step()
        
        # Train the discriminator on the true/generated data
        discriminator_optimizer.zero_grad()
        true_discriminator_out = discriminator(true_data)
        true_discriminator_loss = loss(true_discriminator_out, true_labels)
        
        # add .detach() here think about this
        generator_discriminator_out = discriminator(generated_data.detach())
        generator_discriminator_loss = loss(generator_discriminator_out, torch.zeros(batch_size))
        discriminator_loss = (true_discriminator_loss + generator_discriminator_loss) / 2
        discriminator_loss.backward()
        discriminator_optimizer.step()
        
        print(f"[Iter {i}] [GenLoss {generator_loss.item():0.4f}] [DisLoss {discriminator_loss.item():0.4f}] [Acc {((generated_data.round()*(2**torch.arange(generated_data.shape[1]-1, -1, -1))[None, ...]).sum(1)%2==0).float().sum(0)/generated_data.shape[0]}]")
        if i%500 == 0:
            print(f'[Pred: { (generated_data.round()*(2**torch.arange(generated_data.shape[1]-1, -1, -1))[None, ...]).sum(1) }]')
        if i%500 == 0:
            print(f'[GT: { (true_data*(2**torch.arange(true_data.shape[1]-1, -1, -1))[None, ...]).sum(1) }')

# %%
train()
# Out:
# [Iter 0] [GenLoss 0.7094] [DisLoss 0.7685] [Acc 0.0]
# [Pred: tensor([73.,  1.,  3.,  3.,  3., 33.,  3.,  3.,  1.,  1.,  3., 33., 43.,  1.,
#          1.,  9.], grad_fn=<SumBackward1>)]
# [GT: tensor([116.,   0., 110.,   0., 126.,  30.,  82.,  84.,  76., 106.,  22., 110.,
#         102.,  92., 102.,  10.])
# [Iter 1] [GenLoss 0.7131] [DisLoss 0.7550] [Acc 0.0625]
# [Iter 2] [GenLoss 0.7045] [DisLoss 0.7155] [Acc 0.0]
# [Iter 3] [GenLoss 0.7064] [DisLoss 0.7263] [Acc 0.0]
# [Iter 4] [GenLoss 0.7024] [DisLoss 0.7592] [Acc 0.125]
# [Iter 5] [GenLoss 0.7098] [DisLoss 0.7532] [Acc 0.0]
# [Iter 6] [GenLoss 0.6921] [DisLoss 0.7597] [Acc 0.0625]
# [Iter 7] [GenLoss 0.7074] [DisLoss 0.7395] [Acc 0.0]
# [Iter 8] [GenLoss 0.6894] [DisLoss 0.7929] [Acc 0.0]
# [Iter 9] [GenLoss 0.7037] [DisLoss 0.7439] [Acc 0.0625]
# [Iter 10] [GenLoss 0.6992] [DisLoss 0.7610] [Acc 0.0]
# [Iter 11] [GenLoss 0.6982] [DisLoss 0.7638] [Acc 0.0]
# [Iter 12] [GenLoss 0.6757] [DisLoss 0.7785] [Acc 0.0]
# [Iter 13] [GenLoss 0.6907] [DisLoss 0.7133] [Acc 0.0]
# [Iter 14] [GenLoss 0.6826] [DisLoss 0.7651] [Acc 0.0]
# [Iter 15] [GenLoss 0.6884] [DisLoss 0.7317] [Acc 0.0]
# [Iter 16] [GenLoss 0.6952] [DisLoss 0.7511] [Acc 0.0]
# [Iter 17] [GenLoss 0.6991] [DisLoss 0.7384] [Acc 0.0]
# [Iter 18] [GenLoss 0.6859] [DisLoss 0.7380] [Acc 0.0625]
# [Iter 19] [GenLoss 0.6726] [DisLoss 0.7790] [Acc 0.0]
# [Iter 20] [GenLoss 0.6792] [DisLoss 0.7384] [Acc 0.0]
# [Iter 21] [GenLoss 0.6818] [DisLoss 0.7551] [Acc 0.0]
# [Iter 22] [GenLoss 0.6781] [DisLoss 0.7509] [Acc 0.0]
# [Iter 23] [GenLoss 0.6703] [DisLoss 0.7450] [Acc 0.0]
# [Iter 24] [GenLoss 0.6828] [DisLoss 0.7506] [Acc 0.0]
# [Iter 25] [GenLoss 0.6717] [DisLoss 0.7581] [Acc 0.0]
# [Iter 26] [GenLoss 0.6624] [DisLoss 0.7567] [Acc 0.0]
# [Iter 27] [GenLoss 0.6794] [DisLoss 0.7242] [Acc 0.0]
# [Iter 28] [GenLoss 0.6746] [DisLoss 0.7607] [Acc 0.0]
# [Iter 29] [GenLoss 0.6733] [DisLoss 0.7892] [Acc 0.0625]
# [Iter 30] [GenLoss 0.6600] [DisLoss 0.7471] [Acc 0.0]
# [Iter 31] [GenLoss 0.6735] [DisLoss 0.7001] [Acc 0.0]
# [Iter 32] [GenLoss 0.6714] [DisLoss 0.7192] [Acc 0.0]
# [Iter 33] [GenLoss 0.6604] [DisLoss 0.7596] [Acc 0.0]
# [Iter 34] [GenLoss 0.6565] [DisLoss 0.7784] [Acc 0.0]
# [Iter 35] [GenLoss 0.6597] [DisLoss 0.7768] [Acc 0.0]
# [Iter 36] [GenLoss 0.6572] [DisLoss 0.7815] [Acc 0.0]
# [Iter 37] [GenLoss 0.6556] [DisLoss 0.7607] [Acc 0.0]
# [Iter 38] [GenLoss 0.6551] [DisLoss 0.7408] [Acc 0.0]
# [Iter 39] [GenLoss 0.6517] [DisLoss 0.7892] [Acc 0.0]
# [Iter 40] [GenLoss 0.6593] [DisLoss 0.7841] [Acc 0.0]
# [Iter 41] [GenLoss 0.6526] [DisLoss 0.7722] [Acc 0.0]
# [Iter 42] [GenLoss 0.6633] [DisLoss 0.7562] [Acc 0.0]
# [Iter 43] [GenLoss 0.6573] [DisLoss 0.7649] [Acc 0.0625]
# [Iter 44] [GenLoss 0.6538] [DisLoss 0.7661] [Acc 0.0]
# [Iter 45] [GenLoss 0.6541] [DisLoss 0.7514] [Acc 0.0]
# [Iter 46] [GenLoss 0.6654] [DisLoss 0.7371] [Acc 0.0]
# [Iter 47] [GenLoss 0.6451] [DisLoss 0.7391] [Acc 0.0]
# [Iter 48] [GenLoss 0.6560] [DisLoss 0.7552] [Acc 0.0]
# [Iter 49] [GenLoss 0.6451] [DisLoss 0.7607] [Acc 0.0]
# [Iter 50] [GenLoss 0.6479] [DisLoss 0.7581] [Acc 0.0]
# [Iter 51] [GenLoss 0.6434] [DisLoss 0.7694] [Acc 0.0]
# [Iter 52] [GenLoss 0.6528] [DisLoss 0.7288] [Acc 0.0]
# [Iter 53] [GenLoss 0.6352] [DisLoss 0.7139] [Acc 0.0]
# [Iter 54] [GenLoss 0.6402] [DisLoss 0.7535] [Acc 0.0]
# [Iter 55] [GenLoss 0.6431] [DisLoss 0.7439] [Acc 0.0]
# [Iter 56] [GenLoss 0.6401] [DisLoss 0.7853] [Acc 0.0]
# [Iter 57] [GenLoss 0.6321] [DisLoss 0.7622] [Acc 0.0]
# [Iter 58] [GenLoss 0.6420] [DisLoss 0.7465] [Acc 0.0]
# [Iter 59] [GenLoss 0.6432] [DisLoss 0.7388] [Acc 0.0]
# [Iter 60] [GenLoss 0.6488] [DisLoss 0.7447] [Acc 0.0]
# [Iter 61] [GenLoss 0.6357] [DisLoss 0.7383] [Acc 0.0]
# [Iter 62] [GenLoss 0.6446] [DisLoss 0.7057] [Acc 0.0]
# [Iter 63] [GenLoss 0.6402] [DisLoss 0.7389] [Acc 0.0]
# [Iter 64] [GenLoss 0.6303] [DisLoss 0.7725] [Acc 0.0]
# [Iter 65] [GenLoss 0.6419] [DisLoss 0.7466] [Acc 0.0]
# [Iter 66] [GenLoss 0.6420] [DisLoss 0.7614] [Acc 0.0]
# [Iter 67] [GenLoss 0.6426] [DisLoss 0.7524] [Acc 0.0]
# [Iter 68] [GenLoss 0.6245] [DisLoss 0.7286] [Acc 0.0]
# [Iter 69] [GenLoss 0.6259] [DisLoss 0.7311] [Acc 0.0]
# [Iter 70] [GenLoss 0.6401] [DisLoss 0.7497] [Acc 0.0]
# [Iter 71] [GenLoss 0.6338] [DisLoss 0.7600] [Acc 0.0]
# [Iter 72] [GenLoss 0.6310] [DisLoss 0.7130] [Acc 0.0]
# [Iter 73] [GenLoss 0.6388] [DisLoss 0.7290] [Acc 0.0]
# [Iter 74] [GenLoss 0.6291] [DisLoss 0.7940] [Acc 0.0]
# [Iter 75] [GenLoss 0.6261] [DisLoss 0.7887] [Acc 0.0]
# [Iter 76] [GenLoss 0.6366] [DisLoss 0.7618] [Acc 0.0]
# [Iter 77] [GenLoss 0.6325] [DisLoss 0.7376] [Acc 0.0]
# [Iter 78] [GenLoss 0.6247] [DisLoss 0.7546] [Acc 0.0]
# [Iter 79] [GenLoss 0.6243] [DisLoss 0.7748] [Acc 0.0]
# [Iter 80] [GenLoss 0.6450] [DisLoss 0.7592] [Acc 0.0]
# [Iter 81] [GenLoss 0.6422] [DisLoss 0.7507] [Acc 0.0]
# [Iter 82] [GenLoss 0.6236] [DisLoss 0.7500] [Acc 0.0]
# [Iter 83] [GenLoss 0.6244] [DisLoss 0.7569] [Acc 0.0]
# [Iter 84] [GenLoss 0.6329] [DisLoss 0.7957] [Acc 0.0]
# [Iter 85] [GenLoss 0.6251] [DisLoss 0.7535] [Acc 0.0]
# [Iter 86] [GenLoss 0.6384] [DisLoss 0.7533] [Acc 0.0]
# [Iter 87] [GenLoss 0.6323] [DisLoss 0.7917] [Acc 0.0]
# [Iter 88] [GenLoss 0.6198] [DisLoss 0.7709] [Acc 0.0]
# [Iter 89] [GenLoss 0.6287] [DisLoss 0.7440] [Acc 0.0]
# [Iter 90] [GenLoss 0.6298] [DisLoss 0.7086] [Acc 0.0]
# [Iter 91] [GenLoss 0.6289] [DisLoss 0.7554] [Acc 0.0]
# [Iter 92] [GenLoss 0.6227] [DisLoss 0.7441] [Acc 0.0]
# [Iter 93] [GenLoss 0.6322] [DisLoss 0.7536] [Acc 0.0]
# [Iter 94] [GenLoss 0.6380] [DisLoss 0.7779] [Acc 0.0]
# [Iter 95] [GenLoss 0.6491] [DisLoss 0.7214] [Acc 0.0]
# [Iter 96] [GenLoss 0.6389] [DisLoss 0.7254] [Acc 0.0]
# [Iter 97] [GenLoss 0.6427] [DisLoss 0.7568] [Acc 0.0]
# [Iter 98] [GenLoss 0.6248] [DisLoss 0.7667] [Acc 0.0]
# [Iter 99] [GenLoss 0.6127] [DisLoss 0.7513] [Acc 0.0]
# [Iter 100] [GenLoss 0.6336] [DisLoss 0.7503] [Acc 0.0]
# [Iter 101] [GenLoss 0.6218] [DisLoss 0.7856] [Acc 0.0]
# [Iter 102] [GenLoss 0.6309] [DisLoss 0.7607] [Acc 0.0]
# [Iter 103] [GenLoss 0.6255] [DisLoss 0.7228] [Acc 0.0]
# [Iter 104] [GenLoss 0.6353] [DisLoss 0.7683] [Acc 0.0]
# [Iter 105] [GenLoss 0.6228] [DisLoss 0.7359] [Acc 0.0]
# [Iter 106] [GenLoss 0.6294] [DisLoss 0.7606] [Acc 0.0]
# [Iter 107] [GenLoss 0.6288] [DisLoss 0.7269] [Acc 0.0]
# [Iter 108] [GenLoss 0.6280] [DisLoss 0.7844] [Acc 0.0]
# [Iter 109] [GenLoss 0.6441] [DisLoss 0.7311] [Acc 0.0]
# [Iter 110] [GenLoss 0.6353] [DisLoss 0.7181] [Acc 0.0]
# [Iter 111] [GenLoss 0.6375] [DisLoss 0.7386] [Acc 0.0]
# [Iter 112] [GenLoss 0.6408] [DisLoss 0.7513] [Acc 0.0]
# [Iter 113] [GenLoss 0.6438] [DisLoss 0.7610] [Acc 0.0]
# [Iter 114] [GenLoss 0.6343] [DisLoss 0.7405] [Acc 0.0]
# [Iter 115] [GenLoss 0.6390] [DisLoss 0.7540] [Acc 0.0]
# [Iter 116] [GenLoss 0.6387] [DisLoss 0.7749] [Acc 0.0]
# [Iter 117] [GenLoss 0.6301] [DisLoss 0.7227] [Acc 0.0]
# [Iter 118] [GenLoss 0.6476] [DisLoss 0.7414] [Acc 0.0]
# [Iter 119] [GenLoss 0.6423] [DisLoss 0.7400] [Acc 0.0]
# [Iter 120] [GenLoss 0.6319] [DisLoss 0.7559] [Acc 0.0]
# [Iter 121] [GenLoss 0.6380] [DisLoss 0.7435] [Acc 0.0]
# [Iter 122] [GenLoss 0.6345] [DisLoss 0.7667] [Acc 0.0]
# [Iter 123] [GenLoss 0.6253] [DisLoss 0.7392] [Acc 0.0]
# [Iter 124] [GenLoss 0.6365] [DisLoss 0.7200] [Acc 0.0]
# [Iter 125] [GenLoss 0.6231] [DisLoss 0.7479] [Acc 0.0]
# [Iter 126] [GenLoss 0.6304] [DisLoss 0.7535] [Acc 0.0]
# [Iter 127] [GenLoss 0.6482] [DisLoss 0.7437] [Acc 0.0]
# [Iter 128] [GenLoss 0.6287] [DisLoss 0.7475] [Acc 0.0]
# [Iter 129] [GenLoss 0.6376] [DisLoss 0.7371] [Acc 0.0]
# [Iter 130] [GenLoss 0.6465] [DisLoss 0.7787] [Acc 0.0]
# [Iter 131] [GenLoss 0.6422] [DisLoss 0.7282] [Acc 0.0]
# [Iter 132] [GenLoss 0.6370] [DisLoss 0.7480] [Acc 0.0]
# [Iter 133] [GenLoss 0.6389] [DisLoss 0.7497] [Acc 0.0]
# [Iter 134] [GenLoss 0.6464] [DisLoss 0.7648] [Acc 0.0]
# [Iter 135] [GenLoss 0.6332] [DisLoss 0.7776] [Acc 0.0]
# [Iter 136] [GenLoss 0.6474] [DisLoss 0.7375] [Acc 0.0]
# [Iter 137] [GenLoss 0.6353] [DisLoss 0.7621] [Acc 0.0]
# [Iter 138] [GenLoss 0.6325] [DisLoss 0.7899] [Acc 0.0]
# [Iter 139] [GenLoss 0.6338] [DisLoss 0.7525] [Acc 0.0]
# [Iter 140] [GenLoss 0.6394] [DisLoss 0.7698] [Acc 0.0]
# [Iter 141] [GenLoss 0.6469] [DisLoss 0.7484] [Acc 0.0]
# [Iter 142] [GenLoss 0.6404] [DisLoss 0.7534] [Acc 0.0]
# [Iter 143] [GenLoss 0.6375] [DisLoss 0.7745] [Acc 0.0]
# [Iter 144] [GenLoss 0.6453] [DisLoss 0.7330] [Acc 0.0]
# [Iter 145] [GenLoss 0.6343] [DisLoss 0.7327] [Acc 0.0]
# [Iter 146] [GenLoss 0.6339] [DisLoss 0.7663] [Acc 0.0]
# [Iter 147] [GenLoss 0.6424] [DisLoss 0.7464] [Acc 0.0]
# [Iter 148] [GenLoss 0.6347] [DisLoss 0.7465] [Acc 0.0]
# [Iter 149] [GenLoss 0.6317] [DisLoss 0.7305] [Acc 0.0]
# [Iter 150] [GenLoss 0.6432] [DisLoss 0.7280] [Acc 0.0]
# [Iter 151] [GenLoss 0.6391] [DisLoss 0.7844] [Acc 0.0]
# [Iter 152] [GenLoss 0.6562] [DisLoss 0.7355] [Acc 0.0]
# [Iter 153] [GenLoss 0.6349] [DisLoss 0.7196] [Acc 0.0]
# [Iter 154] [GenLoss 0.6420] [DisLoss 0.7523] [Acc 0.0]
# [Iter 155] [GenLoss 0.6400] [DisLoss 0.7667] [Acc 0.0]
# [Iter 156] [GenLoss 0.6524] [DisLoss 0.7631] [Acc 0.0]
# [Iter 157] [GenLoss 0.6422] [DisLoss 0.7910] [Acc 0.0]
# [Iter 158] [GenLoss 0.6511] [DisLoss 0.7341] [Acc 0.0]
# [Iter 159] [GenLoss 0.6377] [DisLoss 0.7294] [Acc 0.0]
# [Iter 160] [GenLoss 0.6306] [DisLoss 0.7334] [Acc 0.0]
# [Iter 161] [GenLoss 0.6472] [DisLoss 0.7243] [Acc 0.0]
# [Iter 162] [GenLoss 0.6351] [DisLoss 0.7638] [Acc 0.0]
# [Iter 163] [GenLoss 0.6443] [DisLoss 0.7547] [Acc 0.0]
# [Iter 164] [GenLoss 0.6574] [DisLoss 0.7298] [Acc 0.0]
# [Iter 165] [GenLoss 0.6354] [DisLoss 0.7513] [Acc 0.0]
# [Iter 166] [GenLoss 0.6534] [DisLoss 0.7409] [Acc 0.0]
# [Iter 167] [GenLoss 0.6360] [DisLoss 0.7430] [Acc 0.0]
# [Iter 168] [GenLoss 0.6490] [DisLoss 0.7355] [Acc 0.0]
# [Iter 169] [GenLoss 0.6501] [DisLoss 0.7461] [Acc 0.0]
# [Iter 170] [GenLoss 0.6552] [DisLoss 0.7453] [Acc 0.0]
# [Iter 171] [GenLoss 0.6516] [DisLoss 0.7699] [Acc 0.0]
# [Iter 172] [GenLoss 0.6504] [DisLoss 0.7327] [Acc 0.0]
# [Iter 173] [GenLoss 0.6492] [DisLoss 0.7287] [Acc 0.0]
# [Iter 174] [GenLoss 0.6494] [DisLoss 0.7525] [Acc 0.0]
# [Iter 175] [GenLoss 0.6526] [DisLoss 0.7564] [Acc 0.0]
# [Iter 176] [GenLoss 0.6456] [DisLoss 0.7653] [Acc 0.0]
# [Iter 177] [GenLoss 0.6541] [DisLoss 0.7567] [Acc 0.0]
# [Iter 178] [GenLoss 0.6584] [DisLoss 0.7671] [Acc 0.0]
# [Iter 179] [GenLoss 0.6529] [DisLoss 0.7373] [Acc 0.0]
# [Iter 180] [GenLoss 0.6511] [DisLoss 0.7477] [Acc 0.0]
# [Iter 181] [GenLoss 0.6508] [DisLoss 0.7233] [Acc 0.0]
# [Iter 182] [GenLoss 0.6575] [DisLoss 0.7482] [Acc 0.0]
# [Iter 183] [GenLoss 0.6527] [DisLoss 0.7535] [Acc 0.0]
# [Iter 184] [GenLoss 0.6559] [DisLoss 0.7554] [Acc 0.0]
# [Iter 185] [GenLoss 0.6614] [DisLoss 0.7112] [Acc 0.0]
# [Iter 186] [GenLoss 0.6573] [DisLoss 0.7256] [Acc 0.0]
# [Iter 187] [GenLoss 0.6616] [DisLoss 0.7502] [Acc 0.0]
# [Iter 188] [GenLoss 0.6566] [DisLoss 0.7230] [Acc 0.0]
# [Iter 189] [GenLoss 0.6576] [DisLoss 0.7366] [Acc 0.0]
# [Iter 190] [GenLoss 0.6519] [DisLoss 0.7207] [Acc 0.0]
# [Iter 191] [GenLoss 0.6546] [DisLoss 0.7586] [Acc 0.0]
# [Iter 192] [GenLoss 0.6616] [DisLoss 0.7311] [Acc 0.0]
# [Iter 193] [GenLoss 0.6597] [DisLoss 0.7424] [Acc 0.0]
# [Iter 194] [GenLoss 0.6614] [DisLoss 0.7304] [Acc 0.0]
# [Iter 195] [GenLoss 0.6549] [DisLoss 0.7497] [Acc 0.0]
# [Iter 196] [GenLoss 0.6486] [DisLoss 0.7244] [Acc 0.0]
# [Iter 197] [GenLoss 0.6618] [DisLoss 0.7562] [Acc 0.0]
# [Iter 198] [GenLoss 0.6679] [DisLoss 0.7017] [Acc 0.0]
# [Iter 199] [GenLoss 0.6651] [DisLoss 0.7387] [Acc 0.0]
# [Iter 200] [GenLoss 0.6642] [DisLoss 0.7551] [Acc 0.0]
# [Iter 201] [GenLoss 0.6628] [DisLoss 0.7183] [Acc 0.0]
# [Iter 202] [GenLoss 0.6707] [DisLoss 0.7322] [Acc 0.0]
# [Iter 203] [GenLoss 0.6540] [DisLoss 0.7307] [Acc 0.0]
# [Iter 204] [GenLoss 0.6678] [DisLoss 0.7330] [Acc 0.0]
# [Iter 205] [GenLoss 0.6597] [DisLoss 0.7300] [Acc 0.0]
# [Iter 206] [GenLoss 0.6659] [DisLoss 0.7178] [Acc 0.0]
# [Iter 207] [GenLoss 0.6789] [DisLoss 0.7137] [Acc 0.0]
# [Iter 208] [GenLoss 0.6747] [DisLoss 0.7177] [Acc 0.0]
# [Iter 209] [GenLoss 0.6755] [DisLoss 0.7516] [Acc 0.0]
# [Iter 210] [GenLoss 0.6752] [DisLoss 0.7209] [Acc 0.0]
# [Iter 211] [GenLoss 0.6627] [DisLoss 0.7235] [Acc 0.0]
# [Iter 212] [GenLoss 0.6625] [DisLoss 0.7416] [Acc 0.0]
# [Iter 213] [GenLoss 0.6629] [DisLoss 0.7313] [Acc 0.0]
# [Iter 214] [GenLoss 0.6614] [DisLoss 0.7499] [Acc 0.0]
# [Iter 215] [GenLoss 0.6630] [DisLoss 0.7263] [Acc 0.0]
# [Iter 216] [GenLoss 0.6687] [DisLoss 0.7317] [Acc 0.0]
# [Iter 217] [GenLoss 0.6678] [DisLoss 0.7333] [Acc 0.0]
# [Iter 218] [GenLoss 0.6678] [DisLoss 0.7285] [Acc 0.0]
# [Iter 219] [GenLoss 0.6721] [DisLoss 0.7305] [Acc 0.0]
# [Iter 220] [GenLoss 0.6627] [DisLoss 0.7413] [Acc 0.0]
# [Iter 221] [GenLoss 0.6774] [DisLoss 0.7348] [Acc 0.0]
# [Iter 222] [GenLoss 0.6733] [DisLoss 0.7231] [Acc 0.0]
# [Iter 223] [GenLoss 0.6809] [DisLoss 0.7268] [Acc 0.0]
# [Iter 224] [GenLoss 0.6668] [DisLoss 0.7288] [Acc 0.0]
# [Iter 225] [GenLoss 0.6728] [DisLoss 0.7244] [Acc 0.0]
# [Iter 226] [GenLoss 0.6749] [DisLoss 0.7027] [Acc 0.0]
# [Iter 227] [GenLoss 0.6740] [DisLoss 0.7357] [Acc 0.0]
# [Iter 228] [GenLoss 0.6772] [DisLoss 0.7323] [Acc 0.0]
# [Iter 229] [GenLoss 0.6769] [DisLoss 0.7238] [Acc 0.0]
# [Iter 230] [GenLoss 0.6700] [DisLoss 0.7406] [Acc 0.0]
# [Iter 231] [GenLoss 0.6745] [DisLoss 0.7168] [Acc 0.0]
# [Iter 232] [GenLoss 0.6762] [DisLoss 0.7333] [Acc 0.0]
# [Iter 233] [GenLoss 0.6726] [DisLoss 0.7295] [Acc 0.0]
# [Iter 234] [GenLoss 0.6807] [DisLoss 0.7362] [Acc 0.0]
# [Iter 235] [GenLoss 0.6805] [DisLoss 0.7195] [Acc 0.0]
# [Iter 236] [GenLoss 0.6823] [DisLoss 0.7046] [Acc 0.0]
# [Iter 237] [GenLoss 0.6766] [DisLoss 0.7184] [Acc 0.0]
# [Iter 238] [GenLoss 0.6796] [DisLoss 0.7100] [Acc 0.0]
# [Iter 239] [GenLoss 0.6812] [DisLoss 0.7227] [Acc 0.0]
# [Iter 240] [GenLoss 0.6854] [DisLoss 0.7093] [Acc 0.0]
# [Iter 241] [GenLoss 0.6768] [DisLoss 0.7163] [Acc 0.0]
# [Iter 242] [GenLoss 0.6817] [DisLoss 0.7308] [Acc 0.0]
# [Iter 243] [GenLoss 0.6817] [DisLoss 0.7166] [Acc 0.0]
# [Iter 244] [GenLoss 0.6831] [DisLoss 0.7278] [Acc 0.0]
# [Iter 245] [GenLoss 0.6789] [DisLoss 0.6912] [Acc 0.0]
# [Iter 246] [GenLoss 0.6814] [DisLoss 0.7220] [Acc 0.0]
# [Iter 247] [GenLoss 0.6862] [DisLoss 0.7078] [Acc 0.0]
# [Iter 248] [GenLoss 0.6846] [DisLoss 0.7101] [Acc 0.0]
# [Iter 249] [GenLoss 0.6865] [DisLoss 0.7151] [Acc 0.0]
# [Iter 250] [GenLoss 0.6881] [DisLoss 0.7095] [Acc 0.0]
# [Iter 251] [GenLoss 0.6920] [DisLoss 0.7148] [Acc 0.0]
# [Iter 252] [GenLoss 0.6865] [DisLoss 0.7093] [Acc 0.0]
# [Iter 253] [GenLoss 0.6897] [DisLoss 0.7242] [Acc 0.0]
# [Iter 254] [GenLoss 0.6915] [DisLoss 0.7302] [Acc 0.0]
# [Iter 255] [GenLoss 0.6877] [DisLoss 0.7130] [Acc 0.0]
# [Iter 256] [GenLoss 0.6970] [DisLoss 0.7079] [Acc 0.0]
# [Iter 257] [GenLoss 0.6899] [DisLoss 0.7106] [Acc 0.0]
# [Iter 258] [GenLoss 0.6894] [DisLoss 0.7067] [Acc 0.0]
# [Iter 259] [GenLoss 0.6878] [DisLoss 0.7324] [Acc 0.0]
# [Iter 260] [GenLoss 0.6932] [DisLoss 0.7184] [Acc 0.0]
# [Iter 261] [GenLoss 0.6944] [DisLoss 0.6865] [Acc 0.0]
# [Iter 262] [GenLoss 0.6898] [DisLoss 0.7266] [Acc 0.0]
# [Iter 263] [GenLoss 0.6912] [DisLoss 0.7182] [Acc 0.0]
# [Iter 264] [GenLoss 0.6872] [DisLoss 0.7214] [Acc 0.0]
# [Iter 265] [GenLoss 0.6828] [DisLoss 0.7298] [Acc 0.0]
# [Iter 266] [GenLoss 0.6982] [DisLoss 0.7092] [Acc 0.0]
# [Iter 267] [GenLoss 0.6914] [DisLoss 0.7041] [Acc 0.0]
# [Iter 268] [GenLoss 0.6858] [DisLoss 0.7127] [Acc 0.0]
# [Iter 269] [GenLoss 0.6954] [DisLoss 0.7009] [Acc 0.0]
# [Iter 270] [GenLoss 0.7015] [DisLoss 0.7037] [Acc 0.0]
# [Iter 271] [GenLoss 0.6932] [DisLoss 0.7153] [Acc 0.0]
# [Iter 272] [GenLoss 0.6975] [DisLoss 0.7120] [Acc 0.0]
# [Iter 273] [GenLoss 0.6928] [DisLoss 0.6938] [Acc 0.0]
# [Iter 274] [GenLoss 0.6925] [DisLoss 0.7219] [Acc 0.0]
# [Iter 275] [GenLoss 0.6971] [DisLoss 0.6908] [Acc 0.0]
# [Iter 276] [GenLoss 0.7010] [DisLoss 0.6952] [Acc 0.0]
# [Iter 277] [GenLoss 0.6976] [DisLoss 0.7080] [Acc 0.0]
# [Iter 278] [GenLoss 0.6989] [DisLoss 0.6993] [Acc 0.0]
# [Iter 279] [GenLoss 0.6982] [DisLoss 0.7240] [Acc 0.0]
# [Iter 280] [GenLoss 0.7013] [DisLoss 0.7049] [Acc 0.0]
# [Iter 281] [GenLoss 0.7040] [DisLoss 0.7121] [Acc 0.0]
# [Iter 282] [GenLoss 0.7006] [DisLoss 0.7182] [Acc 0.0]
# [Iter 283] [GenLoss 0.7001] [DisLoss 0.7090] [Acc 0.0]
# [Iter 284] [GenLoss 0.7048] [DisLoss 0.6815] [Acc 0.0]
# [Iter 285] [GenLoss 0.6988] [DisLoss 0.7138] [Acc 0.0]
# [Iter 286] [GenLoss 0.7030] [DisLoss 0.7139] [Acc 0.0]
# [Iter 287] [GenLoss 0.7034] [DisLoss 0.7040] [Acc 0.0]
# [Iter 288] [GenLoss 0.6969] [DisLoss 0.7059] [Acc 0.0]
# [Iter 289] [GenLoss 0.7008] [DisLoss 0.7112] [Acc 0.0]
# [Iter 290] [GenLoss 0.6983] [DisLoss 0.7188] [Acc 0.0]
# [Iter 291] [GenLoss 0.7095] [DisLoss 0.7160] [Acc 0.0]
# [Iter 292] [GenLoss 0.7065] [DisLoss 0.6953] [Acc 0.0]
# [Iter 293] [GenLoss 0.7044] [DisLoss 0.7223] [Acc 0.0]
# [Iter 294] [GenLoss 0.7039] [DisLoss 0.7017] [Acc 0.0]
# [Iter 295] [GenLoss 0.7022] [DisLoss 0.6967] [Acc 0.0]
# [Iter 296] [GenLoss 0.7049] [DisLoss 0.6939] [Acc 0.0]
# [Iter 297] [GenLoss 0.7076] [DisLoss 0.6994] [Acc 0.0]
# [Iter 298] [GenLoss 0.7016] [DisLoss 0.7056] [Acc 0.0]
# [Iter 299] [GenLoss 0.7020] [DisLoss 0.7082] [Acc 0.0]
# [Iter 300] [GenLoss 0.7046] [DisLoss 0.6999] [Acc 0.0]
# [Iter 301] [GenLoss 0.7095] [DisLoss 0.7064] [Acc 0.0]
# [Iter 302] [GenLoss 0.7060] [DisLoss 0.7116] [Acc 0.0]
# [Iter 303] [GenLoss 0.7073] [DisLoss 0.7027] [Acc 0.0]
# [Iter 304] [GenLoss 0.7055] [DisLoss 0.7109] [Acc 0.0]
# [Iter 305] [GenLoss 0.7081] [DisLoss 0.7157] [Acc 0.0]
# [Iter 306] [GenLoss 0.7111] [DisLoss 0.7073] [Acc 0.0]
# [Iter 307] [GenLoss 0.7072] [DisLoss 0.6956] [Acc 0.0]
# [Iter 308] [GenLoss 0.7120] [DisLoss 0.6797] [Acc 0.0]
# [Iter 309] [GenLoss 0.7101] [DisLoss 0.6933] [Acc 0.0]
# [Iter 310] [GenLoss 0.7086] [DisLoss 0.6958] [Acc 0.0]
# [Iter 311] [GenLoss 0.7148] [DisLoss 0.6850] [Acc 0.0]
# [Iter 312] [GenLoss 0.7080] [DisLoss 0.6949] [Acc 0.0]
# [Iter 313] [GenLoss 0.7087] [DisLoss 0.7092] [Acc 0.0]
# [Iter 314] [GenLoss 0.7095] [DisLoss 0.6833] [Acc 0.0]
# [Iter 315] [GenLoss 0.7109] [DisLoss 0.6981] [Acc 0.0]
# [Iter 316] [GenLoss 0.7122] [DisLoss 0.6900] [Acc 0.0]
# [Iter 317] [GenLoss 0.7100] [DisLoss 0.7066] [Acc 0.0]
# [Iter 318] [GenLoss 0.7121] [DisLoss 0.6915] [Acc 0.0]
# [Iter 319] [GenLoss 0.7091] [DisLoss 0.6884] [Acc 0.0]
# [Iter 320] [GenLoss 0.7115] [DisLoss 0.7058] [Acc 0.0]
# [Iter 321] [GenLoss 0.7146] [DisLoss 0.6927] [Acc 0.0]
# [Iter 322] [GenLoss 0.7117] [DisLoss 0.6868] [Acc 0.0]
# [Iter 323] [GenLoss 0.7154] [DisLoss 0.6919] [Acc 0.0]
# [Iter 324] [GenLoss 0.7149] [DisLoss 0.6883] [Acc 0.0]
# [Iter 325] [GenLoss 0.7163] [DisLoss 0.6849] [Acc 0.0]
# [Iter 326] [GenLoss 0.7143] [DisLoss 0.6935] [Acc 0.0]
# [Iter 327] [GenLoss 0.7178] [DisLoss 0.6935] [Acc 0.0]
# [Iter 328] [GenLoss 0.7172] [DisLoss 0.6786] [Acc 0.0]
# [Iter 329] [GenLoss 0.7176] [DisLoss 0.6884] [Acc 0.0]
# [Iter 330] [GenLoss 0.7176] [DisLoss 0.6853] [Acc 0.0]
# [Iter 331] [GenLoss 0.7220] [DisLoss 0.6872] [Acc 0.0]
# [Iter 332] [GenLoss 0.7206] [DisLoss 0.6814] [Acc 0.0]
# [Iter 333] [GenLoss 0.7203] [DisLoss 0.6899] [Acc 0.0]
# [Iter 334] [GenLoss 0.7189] [DisLoss 0.6926] [Acc 0.0]
# [Iter 335] [GenLoss 0.7221] [DisLoss 0.6828] [Acc 0.0]
# [Iter 336] [GenLoss 0.7189] [DisLoss 0.6905] [Acc 0.0]
# [Iter 337] [GenLoss 0.7207] [DisLoss 0.6767] [Acc 0.0]
# [Iter 338] [GenLoss 0.7209] [DisLoss 0.6751] [Acc 0.0]
# [Iter 339] [GenLoss 0.7218] [DisLoss 0.6904] [Acc 0.0]
# [Iter 340] [GenLoss 0.7215] [DisLoss 0.6698] [Acc 0.0]
# [Iter 341] [GenLoss 0.7226] [DisLoss 0.6863] [Acc 0.0]
# [Iter 342] [GenLoss 0.7239] [DisLoss 0.6948] [Acc 0.0]
# [Iter 343] [GenLoss 0.7204] [DisLoss 0.6867] [Acc 0.0]
# [Iter 344] [GenLoss 0.7227] [DisLoss 0.6874] [Acc 0.0]
# [Iter 345] [GenLoss 0.7223] [DisLoss 0.6876] [Acc 0.0]
# [Iter 346] [GenLoss 0.7246] [DisLoss 0.6881] [Acc 0.0]
# [Iter 347] [GenLoss 0.7263] [DisLoss 0.6847] [Acc 0.0]
# [Iter 348] [GenLoss 0.7252] [DisLoss 0.6752] [Acc 0.0]
# [Iter 349] [GenLoss 0.7237] [DisLoss 0.6876] [Acc 0.0]
# [Iter 350] [GenLoss 0.7284] [DisLoss 0.6843] [Acc 0.0]
# [Iter 351] [GenLoss 0.7292] [DisLoss 0.6817] [Acc 0.0]
# [Iter 352] [GenLoss 0.7280] [DisLoss 0.6888] [Acc 0.0]
# [Iter 353] [GenLoss 0.7270] [DisLoss 0.6740] [Acc 0.0]
# [Iter 354] [GenLoss 0.7301] [DisLoss 0.6809] [Acc 0.0]
# [Iter 355] [GenLoss 0.7286] [DisLoss 0.6686] [Acc 0.0]
# [Iter 356] [GenLoss 0.7288] [DisLoss 0.6895] [Acc 0.0]
# [Iter 357] [GenLoss 0.7307] [DisLoss 0.6720] [Acc 0.0]
# [Iter 358] [GenLoss 0.7315] [DisLoss 0.6790] [Acc 0.0]
# [Iter 359] [GenLoss 0.7307] [DisLoss 0.6768] [Acc 0.0]
# [Iter 360] [GenLoss 0.7305] [DisLoss 0.6704] [Acc 0.0]
# [Iter 361] [GenLoss 0.7305] [DisLoss 0.6761] [Acc 0.0]
# [Iter 362] [GenLoss 0.7327] [DisLoss 0.6800] [Acc 0.0]
# [Iter 363] [GenLoss 0.7319] [DisLoss 0.6725] [Acc 0.0]
# [Iter 364] [GenLoss 0.7328] [DisLoss 0.6652] [Acc 0.0]
# [Iter 365] [GenLoss 0.7337] [DisLoss 0.6738] [Acc 0.0]
# [Iter 366] [GenLoss 0.7320] [DisLoss 0.6792] [Acc 0.0]
# [Iter 367] [GenLoss 0.7344] [DisLoss 0.6719] [Acc 0.0]
# [Iter 368] [GenLoss 0.7344] [DisLoss 0.6685] [Acc 0.0]
# [Iter 369] [GenLoss 0.7352] [DisLoss 0.6856] [Acc 0.0]
# [Iter 370] [GenLoss 0.7360] [DisLoss 0.6799] [Acc 0.0]
# [Iter 371] [GenLoss 0.7359] [DisLoss 0.6730] [Acc 0.0]
# [Iter 372] [GenLoss 0.7376] [DisLoss 0.6754] [Acc 0.0]
# [Iter 373] [GenLoss 0.7386] [DisLoss 0.6675] [Acc 0.0]
# [Iter 374] [GenLoss 0.7362] [DisLoss 0.6736] [Acc 0.0]
# [Iter 375] [GenLoss 0.7381] [DisLoss 0.6681] [Acc 0.0]
# [Iter 376] [GenLoss 0.7389] [DisLoss 0.6810] [Acc 0.0]
# [Iter 377] [GenLoss 0.7391] [DisLoss 0.6719] [Acc 0.0]
# [Iter 378] [GenLoss 0.7385] [DisLoss 0.6800] [Acc 0.0]
# [Iter 379] [GenLoss 0.7397] [DisLoss 0.6750] [Acc 0.0]
# [Iter 380] [GenLoss 0.7396] [DisLoss 0.6775] [Acc 0.0]
# [Iter 381] [GenLoss 0.7408] [DisLoss 0.6711] [Acc 0.0]
# [Iter 382] [GenLoss 0.7410] [DisLoss 0.6701] [Acc 0.0]
# [Iter 383] [GenLoss 0.7412] [DisLoss 0.6774] [Acc 0.0]
# [Iter 384] [GenLoss 0.7426] [DisLoss 0.6765] [Acc 0.0]
# [Iter 385] [GenLoss 0.7430] [DisLoss 0.6692] [Acc 0.0]
# [Iter 386] [GenLoss 0.7434] [DisLoss 0.6752] [Acc 0.0]
# [Iter 387] [GenLoss 0.7427] [DisLoss 0.6740] [Acc 0.0]
# [Iter 388] [GenLoss 0.7446] [DisLoss 0.6800] [Acc 0.0]
# [Iter 389] [GenLoss 0.7435] [DisLoss 0.6684] [Acc 0.0]
# [Iter 390] [GenLoss 0.7426] [DisLoss 0.6655] [Acc 0.0]
# [Iter 391] [GenLoss 0.7445] [DisLoss 0.6650] [Acc 0.0]
# [Iter 392] [GenLoss 0.7447] [DisLoss 0.6801] [Acc 0.0]
# [Iter 393] [GenLoss 0.7445] [DisLoss 0.6771] [Acc 0.0]
# [Iter 394] [GenLoss 0.7437] [DisLoss 0.6601] [Acc 0.0]
# [Iter 395] [GenLoss 0.7451] [DisLoss 0.6763] [Acc 0.0]
# [Iter 396] [GenLoss 0.7464] [DisLoss 0.6710] [Acc 0.0]
# [Iter 397] [GenLoss 0.7469] [DisLoss 0.6571] [Acc 0.0]
# [Iter 398] [GenLoss 0.7446] [DisLoss 0.6686] [Acc 0.0]
# [Iter 399] [GenLoss 0.7466] [DisLoss 0.6745] [Acc 0.0]
# [Iter 400] [GenLoss 0.7462] [DisLoss 0.6606] [Acc 0.0]
# [Iter 401] [GenLoss 0.7463] [DisLoss 0.6629] [Acc 0.0]
# [Iter 402] [GenLoss 0.7464] [DisLoss 0.6682] [Acc 0.0]
# [Iter 403] [GenLoss 0.7464] [DisLoss 0.6643] [Acc 0.0]
# [Iter 404] [GenLoss 0.7457] [DisLoss 0.6702] [Acc 0.0]
# [Iter 405] [GenLoss 0.7460] [DisLoss 0.6640] [Acc 0.0]
# [Iter 406] [GenLoss 0.7470] [DisLoss 0.6556] [Acc 0.0]
# [Iter 407] [GenLoss 0.7454] [DisLoss 0.6585] [Acc 0.0]
# [Iter 408] [GenLoss 0.7485] [DisLoss 0.6654] [Acc 0.0]
# [Iter 409] [GenLoss 0.7472] [DisLoss 0.6797] [Acc 0.0]
# [Iter 410] [GenLoss 0.7499] [DisLoss 0.6727] [Acc 0.0]
# [Iter 411] [GenLoss 0.7493] [DisLoss 0.6620] [Acc 0.0]
# [Iter 412] [GenLoss 0.7480] [DisLoss 0.6593] [Acc 0.0]
# [Iter 413] [GenLoss 0.7485] [DisLoss 0.6550] [Acc 0.0]
# [Iter 414] [GenLoss 0.7475] [DisLoss 0.6625] [Acc 0.0]
# [Iter 415] [GenLoss 0.7486] [DisLoss 0.6568] [Acc 0.0]
# [Iter 416] [GenLoss 0.7495] [DisLoss 0.6638] [Acc 0.0]
# [Iter 417] [GenLoss 0.7469] [DisLoss 0.6666] [Acc 0.0]
# [Iter 418] [GenLoss 0.7493] [DisLoss 0.6582] [Acc 0.0]
# [Iter 419] [GenLoss 0.7478] [DisLoss 0.6612] [Acc 0.0]
# [Iter 420] [GenLoss 0.7455] [DisLoss 0.6538] [Acc 0.0]
# [Iter 421] [GenLoss 0.7491] [DisLoss 0.6771] [Acc 0.0]
# [Iter 422] [GenLoss 0.7490] [DisLoss 0.6714] [Acc 0.0]
# [Iter 423] [GenLoss 0.7493] [DisLoss 0.6631] [Acc 0.0]
# [Iter 424] [GenLoss 0.7511] [DisLoss 0.6724] [Acc 0.0]
# [Iter 425] [GenLoss 0.7501] [DisLoss 0.6469] [Acc 0.0]
# [Iter 426] [GenLoss 0.7527] [DisLoss 0.6619] [Acc 0.0]
# [Iter 427] [GenLoss 0.7501] [DisLoss 0.6700] [Acc 0.0]
# [Iter 428] [GenLoss 0.7539] [DisLoss 0.6507] [Acc 0.0]
# [Iter 429] [GenLoss 0.7527] [DisLoss 0.6715] [Acc 0.0625]
# [Iter 430] [GenLoss 0.7509] [DisLoss 0.6616] [Acc 0.0625]
# [Iter 431] [GenLoss 0.7481] [DisLoss 0.6636] [Acc 0.0]
# [Iter 432] [GenLoss 0.7514] [DisLoss 0.6545] [Acc 0.0]
# [Iter 433] [GenLoss 0.7520] [DisLoss 0.6642] [Acc 0.0]
# [Iter 434] [GenLoss 0.7562] [DisLoss 0.6667] [Acc 0.0]
# [Iter 435] [GenLoss 0.7510] [DisLoss 0.6586] [Acc 0.0]
# [Iter 436] [GenLoss 0.7531] [DisLoss 0.6594] [Acc 0.0]
# [Iter 437] [GenLoss 0.7562] [DisLoss 0.6561] [Acc 0.0]
# [Iter 438] [GenLoss 0.7539] [DisLoss 0.6519] [Acc 0.0]
# [Iter 439] [GenLoss 0.7578] [DisLoss 0.6495] [Acc 0.0]
# [Iter 440] [GenLoss 0.7548] [DisLoss 0.6602] [Acc 0.0625]
# [Iter 441] [GenLoss 0.7596] [DisLoss 0.6460] [Acc 0.0]
# [Iter 442] [GenLoss 0.7565] [DisLoss 0.6510] [Acc 0.0625]
# [Iter 443] [GenLoss 0.7557] [DisLoss 0.6530] [Acc 0.0]
# [Iter 444] [GenLoss 0.7562] [DisLoss 0.6535] [Acc 0.0]
# [Iter 445] [GenLoss 0.7578] [DisLoss 0.6679] [Acc 0.0]
# [Iter 446] [GenLoss 0.7556] [DisLoss 0.6610] [Acc 0.0]
# [Iter 447] [GenLoss 0.7617] [DisLoss 0.6504] [Acc 0.0]
# [Iter 448] [GenLoss 0.7569] [DisLoss 0.6510] [Acc 0.0]
# [Iter 449] [GenLoss 0.7575] [DisLoss 0.6531] [Acc 0.0]
# [Iter 450] [GenLoss 0.7573] [DisLoss 0.6526] [Acc 0.0]
# [Iter 451] [GenLoss 0.7582] [DisLoss 0.6509] [Acc 0.0625]
# [Iter 452] [GenLoss 0.7587] [DisLoss 0.6471] [Acc 0.0]
# [Iter 453] [GenLoss 0.7552] [DisLoss 0.6511] [Acc 0.0625]
# [Iter 454] [GenLoss 0.7530] [DisLoss 0.6654] [Acc 0.1875]
# [Iter 455] [GenLoss 0.7596] [DisLoss 0.6526] [Acc 0.0]
# [Iter 456] [GenLoss 0.7580] [DisLoss 0.6688] [Acc 0.0625]
# [Iter 457] [GenLoss 0.7593] [DisLoss 0.6567] [Acc 0.0625]
# [Iter 458] [GenLoss 0.7599] [DisLoss 0.6478] [Acc 0.0]
# [Iter 459] [GenLoss 0.7613] [DisLoss 0.6416] [Acc 0.0625]
# [Iter 460] [GenLoss 0.7566] [DisLoss 0.6485] [Acc 0.125]
# [Iter 461] [GenLoss 0.7594] [DisLoss 0.6324] [Acc 0.0]
# [Iter 462] [GenLoss 0.7534] [DisLoss 0.6495] [Acc 0.0]
# [Iter 463] [GenLoss 0.7607] [DisLoss 0.6559] [Acc 0.0625]
# [Iter 464] [GenLoss 0.7665] [DisLoss 0.6515] [Acc 0.0]
# [Iter 465] [GenLoss 0.7613] [DisLoss 0.6393] [Acc 0.0]
# [Iter 466] [GenLoss 0.7644] [DisLoss 0.6531] [Acc 0.0]
# [Iter 467] [GenLoss 0.7569] [DisLoss 0.6439] [Acc 0.0625]
# [Iter 468] [GenLoss 0.7590] [DisLoss 0.6535] [Acc 0.125]
# [Iter 469] [GenLoss 0.7568] [DisLoss 0.6495] [Acc 0.0]
# [Iter 470] [GenLoss 0.7556] [DisLoss 0.6508] [Acc 0.25]
# [Iter 471] [GenLoss 0.7609] [DisLoss 0.6509] [Acc 0.0625]
# [Iter 472] [GenLoss 0.7643] [DisLoss 0.6427] [Acc 0.0625]
# [Iter 473] [GenLoss 0.7605] [DisLoss 0.6542] [Acc 0.0]
# [Iter 474] [GenLoss 0.7652] [DisLoss 0.6343] [Acc 0.0625]
# [Iter 475] [GenLoss 0.7576] [DisLoss 0.6568] [Acc 0.0]
# [Iter 476] [GenLoss 0.7627] [DisLoss 0.6527] [Acc 0.0625]
# [Iter 477] [GenLoss 0.7596] [DisLoss 0.6474] [Acc 0.1875]
# [Iter 478] [GenLoss 0.7632] [DisLoss 0.6376] [Acc 0.1875]
# [Iter 479] [GenLoss 0.7578] [DisLoss 0.6435] [Acc 0.125]
# [Iter 480] [GenLoss 0.7547] [DisLoss 0.6577] [Acc 0.125]
# [Iter 481] [GenLoss 0.7584] [DisLoss 0.6553] [Acc 0.125]
# [Iter 482] [GenLoss 0.7611] [DisLoss 0.6357] [Acc 0.125]
# [Iter 483] [GenLoss 0.7595] [DisLoss 0.6394] [Acc 0.125]
# [Iter 484] [GenLoss 0.7571] [DisLoss 0.6429] [Acc 0.1875]
# [Iter 485] [GenLoss 0.7582] [DisLoss 0.6443] [Acc 0.125]
# [Iter 486] [GenLoss 0.7587] [DisLoss 0.6429] [Acc 0.0625]
# [Iter 487] [GenLoss 0.7597] [DisLoss 0.6474] [Acc 0.125]
# [Iter 488] [GenLoss 0.7616] [DisLoss 0.6535] [Acc 0.0]
# [Iter 489] [GenLoss 0.7649] [DisLoss 0.6517] [Acc 0.125]
# [Iter 490] [GenLoss 0.7581] [DisLoss 0.6379] [Acc 0.3125]
# [Iter 491] [GenLoss 0.7614] [DisLoss 0.6375] [Acc 0.0625]
# [Iter 492] [GenLoss 0.7556] [DisLoss 0.6411] [Acc 0.125]
# [Iter 493] [GenLoss 0.7616] [DisLoss 0.6459] [Acc 0.3125]
# [Iter 494] [GenLoss 0.7623] [DisLoss 0.6455] [Acc 0.25]
# [Iter 495] [GenLoss 0.7600] [DisLoss 0.6506] [Acc 0.125]
# [Iter 496] [GenLoss 0.7625] [DisLoss 0.6465] [Acc 0.125]
# [Iter 497] [GenLoss 0.7653] [DisLoss 0.6427] [Acc 0.125]
# [Iter 498] [GenLoss 0.7596] [DisLoss 0.6571] [Acc 0.125]
# [Iter 499] [GenLoss 0.7620] [DisLoss 0.6421] [Acc 0.1875]
