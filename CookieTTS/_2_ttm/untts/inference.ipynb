# %% [markdown]
# # 1 - Import Stuff

# %%
import os
import random

import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import librosa
import soundfile

from torch import Tensor
from typing import List, Tuple, Optional
# Out:
# D:\Miniconda\lib\site-packages\librosa\util\decorators.py:9: NumbaDeprecationWarning: An import was requested from a module that has moved location.
# Import requested from: 'numba.decorators', please update to use 'numba.core.decorators' or pin to Numba version 0.48.0. This alias will not be present in Numba version 0.50.0.
#   from numba.decorators import jit as optional_jit
# D:\Miniconda\lib\site-packages\librosa\util\decorators.py:9: NumbaDeprecationWarning: An import was requested from a module that has moved location.
# Import of 'jit' requested from: 'numba.decorators', please update to use 'numba.core.decorators' or pin to Numba version 0.48.0. This alias will not be present in Numba version 0.50.0.
#   from numba.decorators import jit as optional_jit

# %% [markdown]
# # 2 - Define some basic functions
#
# load_untts_checkpoint()
#
# load_waveglow_checkpoint()
#
# text_preprocess()

# %%
def load_untts_checkpoint(path):
    print("Loading UnTTS... ")
    from CookieTTS._2_ttm.untts.model import load_model
    
    assert os.path.exists(path), f"untts checkpoint file at '{path}' does not exist."
    checkpoint_dict = torch.load(path)
    speaker_id_lookup = checkpoint_dict['speaker_id_lookup']
    hparams           = checkpoint_dict['hparams']
    iteration         = checkpoint_dict['iteration']
    
    model_dict        = checkpoint_dict['state_dict']
    model = load_model(hparams)
    model.load_state_dict(model_dict)
    _ = model.cuda().eval().half()
    print("Loaded UnTTS!")
    print(f"This UnTTS model has been trained for {iteration} Iterations.")
    return model, hparams, speaker_id_lookup


def load_waveglow_checkpoint(vocoder_path, config_fpath):
    import json
    
    # Load config file
    with open(config_fpath) as f:
        data = f.read()
    config = json.loads(data)
    train_config = config["train_config"]
    data_config = config["data_config"]
    if 'preempthasis' not in data_config.keys():
        data_config['preempthasis'] = 0.0
    if 'use_logvar_channels' not in data_config.keys():
        data_config['use_logvar_channels'] = False
    if 'load_hidden_from_disk' not in data_config.keys():
        data_config['load_hidden_from_disk'] = False
    if not 'iso226_empthasis' in data_config.keys():
        data_config["iso226_empthasis"] = False
    dist_config = config["dist_config"]
    data_config['n_mel_channels'] = config["waveglow_config"]['n_mel_channels'] if 'n_mel_channels' in config["waveglow_config"].keys() else 160
    vocoder_config = {
        **config["waveglow_config"],
        'win_length': data_config['win_length'],
        'hop_length': data_config['hop_length'],
        'preempthasis': data_config['preempthasis'],
        'n_mel_channels': data_config["n_mel_channels"],
        'use_logvar_channels': data_config["use_logvar_channels"],
        'load_hidden_from_disk': data_config["load_hidden_from_disk"],
        'iso226_empthasis': data_config["iso226_empthasis"]
    }
    print(vocoder_config)
    print(f"Config File from '{config_fpath}' successfully loaded.")
    
    # initialize model
    print("intializing WaveGlow model... ", end="")
    from CookieTTS._4_mtw.waveglow.efficient_model_ax import WaveGlow
    waveglow = WaveGlow(**vocoder_config)#.cuda()
    print("Done!")

    print(f"{sum(p.numel() for p in waveglow.parameters())/1e6:.3f}M Parameters")

    # load checkpoint from file
    print("loading WaveGlow checkpoint... ", end="")
    checkpoint = torch.load(vocoder_path)
    waveglow.load_state_dict(checkpoint['model']) # and overwrite initialized weights with checkpointed weights
    waveglow.half()       # and convert to half precision (2x speed)
    waveglow.cuda().eval()# move to GPU
    if hasattr(waveglow, 'remove_weightnorm'):
        waveglow.remove_weightnorm() # and remove weightnorm (1.3x speed)
    print("Done!")

    print("initializing Denoiser... ", end="")
    cond_channels = vocoder_config['n_mel_channels']*(vocoder_config['use_logvar_channels']+1)
    denoiser = None#Denoiser(waveglow, n_mel_channels=cond_channels)
    print("Done!")
    vocoder_iters = checkpoint['iteration']
    print(f"WaveGlow trained for {vocoder_iters} iterations")
    speaker_lookup = checkpoint['speaker_lookup'] # ids lookup
    training_sigma = train_config['sigma']

    print("Clearing CUDA Cache... ", end='')
    del checkpoint
    torch.cuda.empty_cache()
    print("Done!")

    import gc # prints currently alive Tensors and Variables  # - And fixes the memory leak? I guess poking the leak with a stick is the answer for now.
    for obj in gc.get_objects():
        try:
            if torch.is_tensor(obj) or (hasattr(obj, 'data') and torch.is_tensor(obj.data)):
                pass#print(type(obj), obj.size())
        except:
            pass
    
    return waveglow, denoiser, training_sigma, speaker_lookup, vocoder_config

# %%
import json
from CookieTTS.utils.text import text_to_sequence
from CookieTTS.utils.text.ARPA import ARPA

# torchMoji imports
import csv
import numpy as np
import os
from CookieTTS.utils.torchmoji.sentence_tokenizer import SentenceTokenizer
from CookieTTS.utils.torchmoji.model_def import torchmoji_feature_encoding
from CookieTTS.utils.torchmoji.global_variables import PRETRAINED_PATH, VOCAB_PATH
from CookieTTS.utils.dataset.utils import load_filepaths_and_text

class preprocess():
    def __init__(self, hparams, dict_path, speaker_ids):
        self.text_cleaners = hparams.text_cleaners
        self.arpa = ARPA(dict_path)
        self.speaker_ids = speaker_ids
        self.start_token = hparams.start_token
        self.stop_token = hparams.stop_token
        
        print(f'Tokenizing using dictionary from {VOCAB_PATH}')
        maxlen = 128
        with open(VOCAB_PATH, 'r') as f:
            vocabulary = json.load(f)
        self.tm_tokenizer = SentenceTokenizer(vocabulary, maxlen)
        del vocabulary
        
        print('Loading TorchMoji model from {}.'.format(PRETRAINED_PATH))
        self.tm_model = torchmoji_feature_encoding(PRETRAINED_PATH)
        self.tm_embedding = hparams.torchMoji_attDim
    
    def get_item(self, texts, use_arpa):
        if type(texts) == str:
            texts = [texts,]
        B = len(texts)
        
        text_tensors = []
        for text in texts:
            text = f'{self.start_token}{text}{self.stop_token}'
            text = self.arpa.get(text) if use_arpa else text
            text = self.get_text(text) # convert text into tensor representation
            text_tensors.append(text)
        del texts
        
        max_length = max([len(textt) for textt in text_tensors])
        
        texts = torch.zeros(B, max_length).long() # LongTensor[B, enc_T]
        for i, text in enumerate(text_tensors):
            texts[i, :text.shape[0]] = text
        return texts
    
    def get_text(self, text):
        text_norm = torch.LongTensor(text_to_sequence(text, self.text_cleaners))
        return text_norm
    
    def get_speaker_id(self, ext_speaker_ids):
        if (type(ext_speaker_ids) == str) or (type(ext_speaker_ids) == int):
            if int(ext_speaker_ids) in self.speaker_ids:
                speaker_ids = self.speaker_ids[int(ext_speaker_ids)]
            else:
                speaker_ids = 0
            speaker_ids =  torch.LongTensor([speaker_ids])
            # [1]
        else:
            speaker_ids = torch.LongTensor([self.speaker_ids[int(ext_speaker_id)] for ext_speaker_id in ext_speaker_ids])
            # [B]
        return speaker_ids
    
    def get_sylps(self, sylps):
        if type(sylps) == int:
            sylps = float(sylps)
        if sylps is None:
            pass
        elif type(sylps) == torch.Tensor:
            pass
        elif type(sylps) == float:
            sylps = torch.FloatTensor([sylps,])
        else:
            sylps = [float(x) for x in sylps]
            sylps = torch.FloatTensor(sylps)
        return sylps
    
    def get_torchmoji_hidden(self, texts, BATCH_SIZE=64):
        if type(texts) == str:
            texts = [texts,]
        B = len(texts)
        
        torchmoji_hdn = torch.zeros(B, int(self.tm_embedding))
        
        for i in range(0, B, BATCH_SIZE):
            texts_batch = texts[i:i+BATCH_SIZE]
            texts_batch = [x.split("|")[1] if ("|" in x and len(x.split("|"))==2 ) else x for x in texts_batch]
            
            tokenized, _, _ = self.tm_tokenizer.tokenize_sentences(texts_batch)# [B, Embed]
            embedding = self.tm_model(tokenized)# returns np array [B, Embed]
            torchmoji_hdn[i:i+BATCH_SIZE] = torch.from_numpy(embedding)
        
        return torchmoji_hdn
    
    def __call__(self,
            texts,
            ext_speaker_ids,
            sylps=None, # List of str or List of float or FloatTensor[B]
            use_arpa=True,
            ):
        # get torchMoji hidden state for each text
        torchmoji_hdn = self.get_torchmoji_hidden(texts)# -> FloatTensor[B, torchMoji_dim]
        
        # convert from texts to Tensors for model input
        texts       = self.get_item(texts, use_arpa)# -> LongTensor[B, enc_T]
        
        # convert external speaker ids to internal
        speaker_ids = self.get_speaker_id(ext_speaker_ids)# -> IntTensor[B]
        
        # ensure sylps is FloatTensor[B] or None if different type
        sylps       = self.get_sylps(sylps)
        
        return texts, speaker_ids, torchmoji_hdn, sylps

# %% [markdown]
# # 3 - Inference Config

# %%
config = {
    "dict_path":      "../../dict/merged.dict.txt",
    "untts_path":    r"G:\TwiBot\CookiePPPTTS\CookieTTS\_2_ttm\untts\outdir\best_model",
    "vocoder_path":  r"H:\TTCheckpoints\waveflow\4thLargeKernels\WG_24_Flow_AEF6\best_val_model",
    "vocoder_config":r"H:\TTCheckpoints\waveflow\4thLargeKernels\WG_24_Flow_AEF6\config.json",
}

# %%
waveglow, _, wg_sigma, wg_speaker_ids, wg_config = load_waveglow_checkpoint(
                                            config["vocoder_path"], config["vocoder_config"])
# Out:
# {'n_mel_channels': 256, 'speaker_embed': 32, 'shift_spect': 0.0, 'scale_spect': 1.0, 'preceived_vol_scaling': False, 'waveflow': False, 'channel_mixing': '1x1conv', 'mix_first': True, 'n_flows': 24, 'n_group': 24, 'n_early_every': 24, 'n_early_size': 2, 'memory_efficient': 1.0, 'spect_scaling': False, 'upsample_mode': 'normal', 'WN_config': {'gated_unit': 'GTU', 'n_layers': 8, 'n_channels': 384, 'kernel_size_w': 3, 'n_layers_dilations_w': None, 'n_layers_dilations_h': 1, 'speaker_embed_dim': 0, 'rezero': False, 'transposed_conv_hidden_dim': 256, 'transposed_conv_kernel_size': [2, 3, 5], 'transposed_conv_scales': None, 'cond_layers': 1, 'cond_activation_func': 'lrelu', 'cond_out_activation_func': False, 'negative_slope': 0.5, 'cond_hidden_channels': 256, 'cond_kernel_size': 1, 'cond_padding_mode': 'zeros', 'seperable_conv': False, 'res_skip': True, 'merge_res_skip': False, 'upsample_mode': 'linear'}, 'cond_layers': 4, 'cond_activation_func': 'lrelu', 'negative_slope': 0.1, 'cond_hidden_channels': 1024, 'cond_output_channels': 1024, 'cond_residual': '1x1conv', 'cond_res_rezero': True, 'cond_kernel_size': 1, 'cond_padding_mode': 'zeros', 'upsample_first': True, 'transposed_conv_hidden_dim': 1024, 'transposed_conv_kernel_size': [4, 9, 5], 'transposed_conv_scales': [2, 3, 5], 'transposed_conv_output_dim': 512, 'transposed_conv_residual': True, 'transposed_conv_residual_linear': True, 'transposed_conv_res_rezero': True, 'group_conv_output_dim': None, 'group_conv_groupped': False, 'win_length': 2400, 'hop_length': 600, 'preempthasis': 0.0, 'use_logvar_channels': False, 'load_hidden_from_disk': False, 'iso226_empthasis': False}
# Config File from 'H:\TTCheckpoints\waveflow\4thLargeKernels\WG_24_Flow_AEF6\config.json' successfully loaded.
# intializing WaveGlow model... Done!
# 319.698M Parameters
# loading WaveGlow checkpoint... Done!
# initializing Denoiser... Done!
# WaveGlow trained for 96000 iterations
# Clearing CUDA Cache... Done!

# %%
untts, un_hparams, speaker_ids = load_untts_checkpoint(config['untts_path'])
# Out:
# Loading UnTTS...
# Loaded UnTTS!
# This UnTTS model has been trained for 47500 Iterations.

# %%
Process = preprocess(un_hparams, config["dict_path"], speaker_ids)
# Out:
# Tokenizing using dictionary from g:\twibot\cookieppptts\CookieTTS\utils/torchmoji/model/vocabulary.json
# Loading TorchMoji model from g:\twibot\cookieppptts\CookieTTS\utils/torchmoji/model/pytorch_model.bin.
# Loading weights for embed.weight
# Loading weights for lstm_0.weight_ih_l0
# Loading weights for lstm_0.weight_hh_l0
# Loading weights for lstm_0.bias_ih_l0
# Loading weights for lstm_0.bias_hh_l0
# Loading weights for lstm_0.weight_ih_l0_reverse
# Loading weights for lstm_0.weight_hh_l0_reverse
# Loading weights for lstm_0.bias_ih_l0_reverse
# Loading weights for lstm_0.bias_hh_l0_reverse
# Loading weights for lstm_1.weight_ih_l0
# Loading weights for lstm_1.weight_hh_l0
# Loading weights for lstm_1.bias_ih_l0
# Loading weights for lstm_1.bias_hh_l0
# Loading weights for lstm_1.weight_ih_l0_reverse
# Loading weights for lstm_1.weight_hh_l0_reverse
# Loading weights for lstm_1.bias_ih_l0_reverse
# Loading weights for lstm_1.bias_hh_l0_reverse
# Loading weights for attention_layer.attention_vector
# Ignoring weights for output_layer.0.weight
# Ignoring weights for output_layer.0.bias

# %% [markdown]
# # 4 - Infer

# %%
text = """
Aeron, a human man is transported to Equestria through means unknown. After appearing in the Everfree forest, he is attacked and killed by the malicious Timber Wolves. But his story does not end there. For he is reborn as something new to Equestria. But will this new being find acceptance among the Ponies? And how will his presence change the course of events as we know them? Only time will tell!
""".replace("\n","")
speaker_id = 167
sylps = None

texts, speaker_ids, torchmoji_hdn, sylps = Process(text, speaker_id, sylps, use_arpa=False)

ttm_dict = untts.inference(texts, speaker_ids, torchmoji_hdn, sylps,
                          mel_sigma=0.99, dur_sigma=0.95, var_sigma=0.8)

print(ttm_dict['spect'].shape)

audio_batch = waveglow.infer(ttm_dict['spect'], speaker_ids=speaker_ids.cuda(), sigma=wg_sigma*0.95)
audio_batch = audio_batch.cpu().float()

import IPython.display as ipd
ipd.display(ipd.Audio(audio_batch[0].cpu().numpy(), rate=48000))

torch.set_printoptions(sci_mode=False)
char_durs   = ttm_dict['char_durs'].view(-1)
char_voiced = ttm_dict['char_voiced'].view(-1)
char_f0     = ttm_dict['char_f0'].view(-1)
char_energy = ttm_dict['char_energy'].view(-1)
for i, (char, dur, voiced, f0, energy) in enumerate(zip(text, char_durs, char_voiced, char_f0, char_energy)):
    print(f"{i:>3} | '{char}' | {(1000.*dur.item()*un_hparams.hop_length)/un_hparams.sampling_rate:4.0f}ms | {voiced.item():.1f}%voiced | {f0.item() if voiced.item() > 0.1 else 0.0:5.1f}hz | {energy*4:5.1f}RMS Energy dB")
torch.set_printoptions(sci_mode=True)
# Out:
# torch.Size([1, 256, 1623])
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#   0 | 'A' |   43ms | 0.6%voiced | 352.0hz |  57.5RMS Energy dB
#   1 | 'e' |  103ms | 0.7%voiced | 361.8hz |  79.0RMS Energy dB
#   2 | 'r' |   82ms | 1.0%voiced | 379.0hz |  65.8RMS Energy dB
#   3 | 'o' |   77ms | 1.0%voiced | 434.5hz |  53.4RMS Energy dB
#   4 | 'n' |  100ms | 0.9%voiced | 397.2hz |  64.8RMS Energy dB
#   5 | ',' |   92ms | 1.0%voiced | 431.2hz |  53.3RMS Energy dB
#   6 | ' ' |  110ms | 0.6%voiced | 334.5hz |  58.7RMS Energy dB
#   7 | 'a' |   25ms | 0.6%voiced | 319.2hz |  63.1RMS Energy dB
#   8 | ' ' |   45ms | 0.6%voiced | 295.2hz |  53.0RMS Energy dB
#   9 | 'h' |   75ms | 0.7%voiced | 280.5hz |  65.3RMS Energy dB
#  10 | 'u' |   72ms | 0.2%voiced | 299.8hz |  51.0RMS Energy dB
#  11 | 'm' |   55ms | 0.8%voiced | 321.8hz |  50.0RMS Energy dB
#  12 | 'a' |  133ms | 1.0%voiced | 331.8hz |  56.9RMS Energy dB
#  13 | 'n' |   55ms | 1.0%voiced | 303.2hz |  62.0RMS Energy dB
#  14 | ' ' |   62ms | 1.0%voiced | 329.2hz |  50.7RMS Energy dB
#  15 | 'm' |   24ms | 1.0%voiced | 313.0hz |  61.0RMS Energy dB
#  16 | 'a' |   33ms | 1.0%voiced | 309.2hz |  64.5RMS Energy dB
#  17 | 'n' |   84ms | 1.0%voiced | 326.8hz |  57.9RMS Energy dB
#  18 | ' ' |   46ms | 1.0%voiced | 313.0hz |  61.4RMS Energy dB
#  19 | 'i' |   17ms | 0.9%voiced | 267.8hz |  66.5RMS Energy dB
#  20 | 's' |   32ms | 0.9%voiced | 268.8hz |  55.8RMS Energy dB
#  21 | ' ' |  123ms | 0.4%voiced | 296.2hz |  90.1RMS Energy dB
#  22 | 't' |   33ms | 0.2%voiced | 385.0hz |  96.4RMS Energy dB
#  23 | 'r' |   47ms | 0.1%voiced | 347.8hz |  55.6RMS Energy dB
#  24 | 'a' |   45ms | 0.7%voiced | 280.5hz |  52.6RMS Energy dB
#  25 | 'n' |  105ms | 1.0%voiced | 259.5hz |  50.9RMS Energy dB
#  26 | 's' |   25ms | 0.9%voiced | 313.0hz |  47.5RMS Energy dB
#  27 | 'p' |   72ms | 0.5%voiced | 309.2hz |  94.5RMS Energy dB
#  28 | 'o' |   65ms | 0.2%voiced | 290.5hz |  55.2RMS Energy dB
#  29 | 'r' |   86ms | 0.7%voiced | 313.0hz |  56.5RMS Energy dB
#  30 | 't' |   35ms | 0.9%voiced | 326.8hz |  47.2RMS Energy dB
#  31 | 'e' |   23ms | 0.6%voiced | 324.2hz |  51.3RMS Energy dB
#  32 | 'd' |   36ms | 0.4%voiced | 301.0hz |  62.5RMS Energy dB
#  33 | ' ' |   23ms | 0.4%voiced | 299.8hz |  87.8RMS Energy dB
#  34 | 't' |   45ms | 0.2%voiced | 353.2hz |  61.7RMS Energy dB
#  35 | 'o' |   20ms | 0.4%voiced | 338.5hz |  52.1RMS Energy dB
#  36 | ' ' |   60ms | 0.9%voiced | 274.0hz |  79.0RMS Energy dB
#  37 | 'E' |   17ms | 0.9%voiced | 321.8hz |  60.2RMS Energy dB
#  38 | 'q' |   61ms | 0.5%voiced | 330.5hz |  58.5RMS Energy dB
#  39 | 'u' |   61ms | 0.2%voiced | 308.0hz |  51.5RMS Energy dB
#  40 | 'e' |   57ms | 0.8%voiced | 286.0hz |  52.6RMS Energy dB
#  41 | 's' |   71ms | 0.9%voiced | 333.2hz |  45.8RMS Energy dB
#  42 | 't' |   70ms | 0.6%voiced | 347.8hz |  65.6RMS Energy dB
#  43 | 'r' |   51ms | 0.9%voiced | 338.5hz |  50.6RMS Energy dB
#  44 | 'i' |   16ms | 1.0%voiced | 417.8hz |  50.6RMS Energy dB
#  45 | 'a' |   49ms | 1.0%voiced | 560.0hz |  62.3RMS Energy dB
#  46 | ' ' |   53ms | 0.9%voiced | 400.2hz |  46.4RMS Energy dB
#  47 | 't' |   26ms | 0.3%voiced | 343.8hz |  42.8RMS Energy dB
#  48 | 'h' |   67ms | 0.2%voiced | 304.5hz |  56.3RMS Energy dB
#  49 | 'r' |   22ms | 0.7%voiced | 368.8hz |  58.2RMS Energy dB
#  50 | 'o' |   20ms | 0.9%voiced | 302.2hz |  51.6RMS Energy dB
#  51 | 'u' |   37ms | 0.5%voiced | 302.2hz |  75.1RMS Energy dB
#  52 | 'g' |   46ms | 0.9%voiced | 250.5hz |  65.4RMS Energy dB
#  53 | 'h' |   18ms | 0.8%voiced | 292.8hz |  49.9RMS Energy dB
#  54 | ' ' |   10ms | 1.0%voiced | 286.0hz |  60.9RMS Energy dB
#  55 | 'm' |   28ms | 1.0%voiced | 330.5hz |  63.9RMS Energy dB
#  56 | 'e' |   48ms | 1.0%voiced | 329.2hz |  60.2RMS Energy dB
#  57 | 'a' |   52ms | 1.0%voiced | 394.0hz |  63.6RMS Energy dB
#  58 | 'n' |   33ms | 1.0%voiced | 392.5hz |  54.4RMS Energy dB
#  59 | 's' |   89ms | 1.0%voiced | 356.0hz |  72.9RMS Energy dB
#  60 | ' ' |   99ms | 1.0%voiced | 350.5hz |  78.9RMS Energy dB
#  61 | 'u' |   63ms | 0.9%voiced | 383.5hz |  64.8RMS Energy dB
#  62 | 'n' |  112ms | 0.9%voiced | 392.5hz |  64.2RMS Energy dB
#  63 | 'k' |   47ms | 0.9%voiced | 346.5hz |  66.5RMS Energy dB
#  64 | 'n' |   23ms | 0.9%voiced | 298.8hz |  64.5RMS Energy dB
#  65 | 'o' |   60ms | 0.9%voiced | 273.0hz |  62.1RMS Energy dB
#  66 | 'w' |  119ms | 1.0%voiced | 214.2hz |  56.1RMS Energy dB
#  67 | 'n' |   55ms | 0.7%voiced | 295.2hz |  60.1RMS Energy dB
#  68 | '.' |  129ms | 0.8%voiced | 200.5hz |  94.2RMS Energy dB
#  69 | ' ' |  111ms | 0.6%voiced | 315.5hz |  77.2RMS Energy dB
#  70 | 'A' |   37ms | 0.5%voiced | 294.0hz |  49.4RMS Energy dB
#  71 | 'f' |  153ms | 0.8%voiced | 331.8hz |  51.7RMS Energy dB
#  72 | 't' |   83ms | 0.2%voiced | 357.5hz |  46.9RMS Energy dB
#  73 | 'e' |   31ms | 0.3%voiced | 389.5hz |  56.7RMS Energy dB
#  74 | 'r' |   15ms | 0.7%voiced | 453.5hz |  55.6RMS Energy dB
#  75 | ' ' |   61ms | 0.9%voiced | 388.0hz |  57.6RMS Energy dB
#  76 | 'a' |   21ms | 1.0%voiced | 444.8hz |  47.6RMS Energy dB
#  77 | 'p' |   59ms | 0.9%voiced | 482.8hz |  49.2RMS Energy dB
#  78 | 'p' |   32ms | 0.7%voiced | 434.5hz |  52.4RMS Energy dB
#  79 | 'e' |   78ms | 0.3%voiced | 377.5hz |  51.2RMS Energy dB
#  80 | 'a' |   56ms | 1.0%voiced | 331.8hz |  67.6RMS Energy dB
#  81 | 'r' |   45ms | 1.0%voiced | 352.0hz |  66.9RMS Energy dB
#  82 | 'i' |   63ms | 0.9%voiced | 409.8hz |  54.2RMS Energy dB
#  83 | 'n' |   64ms | 1.0%voiced | 315.5hz |  48.2RMS Energy dB
#  84 | 'g' |   54ms | 1.0%voiced | 288.2hz |  58.9RMS Energy dB
#  85 | ' ' |    9ms | 1.0%voiced | 307.0hz |  58.1RMS Energy dB
#  86 | 'i' |    9ms | 1.0%voiced | 326.8hz |  57.4RMS Energy dB
#  87 | 'n' |   27ms | 1.0%voiced | 377.5hz |  42.4RMS Energy dB
#  88 | ' ' |   33ms | 1.0%voiced | 311.8hz |  77.8RMS Energy dB
#  89 | 't' |   16ms | 1.0%voiced | 303.2hz |  51.8RMS Energy dB
#  90 | 'h' |   12ms | 0.9%voiced | 261.5hz |  61.8RMS Energy dB
#  91 | 'e' |    9ms | 0.8%voiced | 299.8hz |  59.2RMS Energy dB
#  92 | ' ' |   51ms | 0.9%voiced | 277.2hz |  47.8RMS Energy dB
#  93 | 'E' |   50ms | 0.4%voiced | 313.0hz |  49.3RMS Energy dB
#  94 | 'v' |  129ms | 0.8%voiced | 289.5hz |  56.5RMS Energy dB
#  95 | 'e' |   58ms | 0.4%voiced | 343.8hz |  29.0RMS Energy dB
#  96 | 'r' |   45ms | 0.9%voiced | 347.8hz |  41.4RMS Energy dB
#  97 | 'f' |   51ms | 0.9%voiced | 350.5hz |  43.0RMS Energy dB
#  98 | 'r' |  129ms | 0.5%voiced | 325.5hz |  41.9RMS Energy dB
#  99 | 'e' |   58ms | 1.0%voiced | 294.0hz |  55.4RMS Energy dB
# 100 | 'e' |   38ms | 0.8%voiced | 314.2hz |  48.8RMS Energy dB
# 101 | ' ' |   43ms | 1.0%voiced | 281.8hz |  54.6RMS Energy dB
# 102 | 'f' |   35ms | 0.7%voiced | 353.2hz |  67.5RMS Energy dB
# 103 | 'o' |   97ms | 0.1%voiced | 338.5hz |  74.3RMS Energy dB
# 104 | 'r' |   48ms | 0.8%voiced | 288.2hz |  65.6RMS Energy dB
# 105 | 'e' |   30ms | 0.9%voiced | 241.9hz |  56.6RMS Energy dB
# 106 | 's' |  118ms | 0.9%voiced | 193.6hz |  42.8RMS Energy dB
# 107 | 't' |  118ms | 0.2%voiced | 289.5hz |  85.9RMS Energy dB
# 108 | ',' |   48ms | 0.0%voiced |   0.0hz |  63.5RMS Energy dB
# 109 | ' ' |  132ms | -0.0%voiced |   0.0hz |  78.2RMS Energy dB
# 110 | 'h' |   66ms | 0.0%voiced |   0.0hz |  75.4RMS Energy dB
# 111 | 'e' |   44ms | 0.1%voiced |   0.0hz |  54.5RMS Energy dB
# 112 | ' ' |   90ms | 0.3%voiced | 345.0hz |  59.8RMS Energy dB
# 113 | 'i' |   16ms | 0.8%voiced | 361.8hz |  69.0RMS Energy dB
# 114 | 's' |   43ms | 0.7%voiced | 335.8hz |  55.0RMS Energy dB
# 115 | ' ' |   57ms | 0.4%voiced | 307.0hz |  63.6RMS Energy dB
# 116 | 'a' |   57ms | -0.0%voiced |   0.0hz |  60.6RMS Energy dB
# 117 | 't' |   54ms | 0.1%voiced | 382.0hz |  70.2RMS Energy dB
# 118 | 't' |   16ms | 0.1%voiced | 356.0hz |  52.6RMS Energy dB
# 119 | 'a' |   53ms | 0.4%voiced | 385.0hz |  80.2RMS Energy dB
# 120 | 'c' |   93ms | 0.9%voiced | 371.8hz |  74.4RMS Energy dB
# 121 | 'k' |   18ms | 0.4%voiced | 377.5hz |  71.8RMS Energy dB
# 122 | 'e' |   49ms | 0.1%voiced | 373.0hz |  67.2RMS Energy dB
# 123 | 'd' |   16ms | 0.2%voiced | 373.0hz |  55.1RMS Energy dB
# 124 | ' ' |   20ms | 0.2%voiced | 346.5hz |  58.0RMS Energy dB
# 125 | 'a' |   10ms | 0.7%voiced | 319.2hz |  60.6RMS Energy dB
# 126 | 'n' |   78ms | 1.0%voiced | 311.8hz |  45.9RMS Energy dB
# 127 | 'd' |   30ms | 0.9%voiced | 316.8hz |  54.6RMS Energy dB
# 128 | ' ' |   17ms | 0.6%voiced | 318.0hz |  68.4RMS Energy dB
# 129 | 'k' |   32ms | 0.5%voiced | 338.5hz |  75.5RMS Energy dB
# 130 | 'i' |   39ms | 0.0%voiced |   0.0hz |  61.0RMS Energy dB
# 131 | 'l' |   15ms | 0.7%voiced | 406.5hz |  71.0RMS Energy dB
# 132 | 'l' |   20ms | 0.7%voiced | 363.0hz |  65.6RMS Energy dB
# 133 | 'e' |   35ms | 0.3%voiced | 358.8hz |  60.4RMS Energy dB
# 134 | 'd' |   12ms | 0.8%voiced | 324.2hz |  57.3RMS Energy dB
# 135 | ' ' |   36ms | 0.9%voiced | 297.5hz |  71.5RMS Energy dB
# 136 | 'b' |   29ms | 0.7%voiced | 298.8hz |  87.4RMS Energy dB
# 137 | 'y' |   25ms | 0.4%voiced | 324.2hz |  66.1RMS Energy dB
# 138 | ' ' |  158ms | 0.9%voiced | 341.0hz |  59.5RMS Energy dB
# 139 | 't' |   24ms | 0.8%voiced | 292.8hz |  60.2RMS Energy dB
# 140 | 'h' |   21ms | 0.5%voiced | 330.5hz |  45.1RMS Energy dB
# 141 | 'e' |    9ms | 0.9%voiced | 421.2hz |  47.6RMS Energy dB
# 142 | ' ' |   17ms | 1.0%voiced | 403.5hz |  62.5RMS Energy dB
# 143 | 'm' |   24ms | 1.0%voiced | 364.5hz |  59.1RMS Energy dB
# 144 | 'a' |   74ms | 1.0%voiced | 304.5hz |  61.5RMS Energy dB
# 145 | 'l' |   67ms | 1.0%voiced | 328.0hz |  70.1RMS Energy dB
# 146 | 'i' |  100ms | 1.0%voiced | 307.0hz |  52.9RMS Energy dB
# 147 | 'c' |   32ms | 1.0%voiced | 279.5hz |  51.4RMS Energy dB
# 148 | 'i' |   63ms | 0.5%voiced | 297.5hz |  44.4RMS Energy dB
# 149 | 'o' |    9ms | 0.5%voiced | 272.0hz |  49.8RMS Energy dB
# 150 | 'u' |   13ms | 0.9%voiced | 224.5hz |  59.9RMS Energy dB
# 151 | 's' |   30ms | 1.0%voiced | 233.5hz |  61.3RMS Energy dB
# 152 | ' ' |   57ms | 0.9%voiced | 240.9hz |  78.4RMS Energy dB
# 153 | 'T' |   36ms | 0.2%voiced | 320.5hz |  67.4RMS Energy dB
# 154 | 'i' |   31ms | 0.3%voiced | 291.8hz |  65.0RMS Energy dB
# 155 | 'm' |   79ms | 0.2%voiced | 318.0hz |  41.1RMS Energy dB
# 156 | 'b' |   67ms | 0.9%voiced | 239.0hz |  57.3RMS Energy dB
# 157 | 'e' |   23ms | 0.8%voiced | 229.9hz |  56.1RMS Energy dB
# 158 | 'r' |   20ms | 1.0%voiced | 244.8hz |  52.5RMS Energy dB
# 159 | ' ' |   28ms | 1.0%voiced | 247.6hz |  73.2RMS Energy dB
# 160 | 'W' |   34ms | 1.0%voiced | 213.4hz |  93.0RMS Energy dB
# 161 | 'o' |   64ms | 1.0%voiced | 263.5hz |  50.7RMS Energy dB
# 162 | 'l' |   97ms | 1.0%voiced | 247.6hz |  54.2RMS Energy dB
# 163 | 'v' |  105ms | 0.8%voiced | 308.0hz |  70.1RMS Energy dB
# 164 | 'e' |   31ms | 0.4%voiced | 388.0hz |  48.3RMS Energy dB
# 165 | 's' |   70ms | 0.1%voiced |   0.0hz |  61.7RMS Energy dB
# 166 | '.' |   75ms | 0.1%voiced |   0.0hz |  50.3RMS Energy dB
# 167 | ' ' |  247ms | 0.0%voiced |   0.0hz | 110.8RMS Energy dB
# 168 | 'B' |   65ms | 0.1%voiced | 353.2hz |  78.8RMS Energy dB
# 169 | 'u' |   21ms | 0.3%voiced | 370.2hz |  57.5RMS Energy dB
# 170 | 't' |   68ms | 0.2%voiced | 419.5hz |  64.9RMS Energy dB
# 171 | ' ' |   41ms | 0.1%voiced | 413.0hz |  41.6RMS Energy dB
# 172 | 'h' |   37ms | 0.3%voiced | 439.8hz |  52.3RMS Energy dB
# 173 | 'i' |   22ms | 0.8%voiced | 634.5hz |  73.1RMS Energy dB
# 174 | 's' |   60ms | 0.9%voiced | 800.0hz |  80.6RMS Energy dB
# 175 | ' ' |   32ms | 0.4%voiced | 479.0hz |  93.1RMS Energy dB
# 176 | 's' |   14ms | 0.4%voiced | 413.0hz |  99.4RMS Energy dB
# 177 | 't' |   38ms | 0.2%voiced | 397.2hz |  99.4RMS Energy dB
# 178 | 'o' |   48ms | 0.1%voiced |   0.0hz |  60.1RMS Energy dB
# 179 | 'r' |  177ms | 0.9%voiced | 484.8hz |  56.9RMS Energy dB
# 180 | 'y' |   59ms | 0.9%voiced | 532.5hz |  56.6RMS Energy dB
# 181 | ' ' |   72ms | 0.9%voiced | 450.0hz |  64.2RMS Energy dB
# 182 | 'd' |   13ms | 1.0%voiced | 436.2hz |  66.8RMS Energy dB
# 183 | 'o' |   30ms | 1.0%voiced | 364.5hz |  79.2RMS Energy dB
# 184 | 'e' |   52ms | 1.0%voiced | 346.5hz |  57.8RMS Energy dB
# 185 | 's' |   11ms | 1.0%voiced | 311.8hz |  63.2RMS Energy dB
# 186 | ' ' |   69ms | 0.7%voiced | 263.5hz |  94.5RMS Energy dB
# 187 | 'n' |   30ms | 0.8%voiced | 342.5hz |  60.6RMS Energy dB
# 188 | 'o' |   18ms | 1.0%voiced | 316.8hz |  55.4RMS Energy dB
# 189 | 't' |   61ms | 1.0%voiced | 342.5hz |  41.5RMS Energy dB
# 190 | ' ' |   38ms | 0.9%voiced | 417.8hz |  54.9RMS Energy dB
# 191 | 'e' |   23ms | 1.0%voiced | 406.5hz |  93.6RMS Energy dB
# 192 | 'n' |  112ms | 1.0%voiced | 459.0hz |  58.3RMS Energy dB
# 193 | 'd' |   47ms | 1.0%voiced | 475.2hz |  61.0RMS Energy dB
# 194 | ' ' |   14ms | 0.9%voiced | 473.5hz |  83.4RMS Energy dB
# 195 | 't' |   22ms | 0.9%voiced | 439.8hz |  70.1RMS Energy dB
# 196 | 'h' |   12ms | 0.7%voiced | 358.8hz |  64.8RMS Energy dB
# 197 | 'e' |   32ms | 0.5%voiced | 374.5hz |  51.3RMS Energy dB
# 198 | 'r' |  126ms | 0.5%voiced | 320.5hz |  60.5RMS Energy dB
# 199 | 'e' |   28ms | 0.4%voiced | 295.2hz |  65.4RMS Energy dB
# 200 | '.' |   64ms | 0.1%voiced | 366.0hz |  88.0RMS Energy dB
# 201 | ' ' |  110ms | 0.1%voiced |   0.0hz |  79.2RMS Energy dB
# 202 | 'F' |   57ms | 0.0%voiced |   0.0hz | 109.1RMS Energy dB
# 203 | 'o' |   80ms | 0.0%voiced |   0.0hz |  71.1RMS Energy dB
# 204 | 'r' |   31ms | 0.3%voiced | 379.0hz |  52.5RMS Energy dB
# 205 | ' ' |   83ms | 0.5%voiced | 334.5hz |  47.9RMS Energy dB
# 206 | 'h' |   29ms | 1.0%voiced | 262.5hz |  60.1RMS Energy dB
# 207 | 'e' |   25ms | 1.0%voiced | 283.8hz |  56.5RMS Energy dB
# 208 | ' ' |   58ms | 0.9%voiced | 343.8hz |  50.2RMS Energy dB
# 209 | 'i' |   11ms | 0.8%voiced | 341.0hz |  60.8RMS Energy dB
# 210 | 's' |   61ms | 0.9%voiced | 371.8hz |  58.9RMS Energy dB
# 211 | ' ' |   65ms | 1.0%voiced | 319.2hz |  56.2RMS Energy dB
# 212 | 'r' |   42ms | 1.0%voiced | 333.2hz |  58.5RMS Energy dB
# 213 | 'e' |   20ms | 1.0%voiced | 373.0hz |  66.8RMS Energy dB
# 214 | 'b' |   53ms | 0.8%voiced | 377.5hz |  61.6RMS Energy dB
# 215 | 'o' |   37ms | 0.2%voiced | 356.0hz |  52.3RMS Energy dB
# 216 | 'r' |   40ms | 0.8%voiced | 391.0hz |  53.2RMS Energy dB
# 217 | 'n' |   52ms | 0.9%voiced | 439.8hz |  50.4RMS Energy dB
# 218 | ' ' |   36ms | 1.0%voiced | 326.8hz |  50.5RMS Energy dB
# 219 | 'a' |   12ms | 0.7%voiced | 281.8hz |  61.4RMS Energy dB
# 220 | 's' |   30ms | 0.2%voiced | 335.8hz |  65.9RMS Energy dB
# 221 | ' ' |   49ms | 0.2%voiced | 304.5hz |  74.4RMS Energy dB
# 222 | 's' |   31ms | 0.4%voiced | 259.5hz | 102.1RMS Energy dB
# 223 | 'o' |   57ms | 0.8%voiced | 251.5hz |  94.2RMS Energy dB
# 224 | 'm' |  123ms | 1.0%voiced | 397.2hz |  60.0RMS Energy dB
# 225 | 'e' |   92ms | 0.9%voiced | 352.0hz |  54.7RMS Energy dB
# 226 | 't' |   14ms | 0.8%voiced | 364.5hz |  73.9RMS Energy dB
# 227 | 'h' |   39ms | 0.3%voiced | 335.8hz |  46.2RMS Energy dB
# 228 | 'i' |   18ms | 0.7%voiced | 330.5hz |  52.3RMS Energy dB
# 229 | 'n' |   64ms | 1.0%voiced | 353.2hz |  45.5RMS Energy dB
# 230 | 'g' |   56ms | 1.0%voiced | 371.8hz |  52.7RMS Energy dB
# 231 | ' ' |   15ms | 1.0%voiced | 360.2hz |  66.4RMS Energy dB
# 232 | 'n' |   21ms | 1.0%voiced | 334.5hz |  54.5RMS Energy dB
# 233 | 'e' |   50ms | 1.0%voiced | 279.5hz |  60.1RMS Energy dB
# 234 | 'w' |   38ms | 1.0%voiced | 302.2hz |  55.2RMS Energy dB
# 235 | ' ' |   51ms | 0.9%voiced | 315.5hz |  42.9RMS Energy dB
# 236 | 't' |   31ms | 0.7%voiced | 342.5hz |  42.2RMS Energy dB
# 237 | 'o' |   34ms | 0.1%voiced | 356.0hz |  58.8RMS Energy dB
# 238 | ' ' |   45ms | 0.5%voiced | 334.5hz |  67.9RMS Energy dB
# 239 | 'E' |   27ms | 0.5%voiced | 311.8hz |  72.6RMS Energy dB
# 240 | 'q' |   53ms | 0.3%voiced | 361.8hz |  64.5RMS Energy dB
# 241 | 'u' |   70ms | 0.4%voiced | 350.5hz |  62.1RMS Energy dB
# 242 | 'e' |   49ms | 1.0%voiced | 353.2hz |  43.0RMS Energy dB
# 243 | 's' |   56ms | 0.6%voiced | 324.2hz |  55.8RMS Energy dB
# 244 | 't' |   95ms | 0.1%voiced | 356.0hz | 100.1RMS Energy dB
# 245 | 'r' |   64ms | 0.1%voiced |   0.0hz |  78.4RMS Energy dB
# 246 | 'i' |  105ms | 0.9%voiced | 338.5hz |  80.5RMS Energy dB
# 247 | 'a' |  241ms | 0.9%voiced | 450.0hz |  48.0RMS Energy dB
# 248 | '.' |  153ms | 0.7%voiced | 639.5hz |  55.0RMS Energy dB
# 249 | ' ' |   69ms | 0.4%voiced | 392.5hz |  69.2RMS Energy dB
# 250 | 'B' |   46ms | 0.3%voiced | 421.2hz |  77.3RMS Energy dB
# 251 | 'u' |   40ms | 0.8%voiced | 382.0hz |  70.2RMS Energy dB
# 252 | 't' |   20ms | 0.3%voiced | 364.5hz |  63.7RMS Energy dB
# 253 | ' ' |   36ms | 0.5%voiced | 339.8hz |  46.0RMS Energy dB
# 254 | 'w' |   53ms | 0.3%voiced | 373.0hz |  65.8RMS Energy dB
# 255 | 'i' |   49ms | 0.4%voiced | 376.0hz |  68.3RMS Energy dB
# 256 | 'l' |   15ms | 0.7%voiced | 405.0hz |  66.1RMS Energy dB
# 257 | 'l' |   24ms | 0.9%voiced | 414.5hz |  53.0RMS Energy dB
# 258 | ' ' |   48ms | 0.9%voiced | 409.8hz |  46.8RMS Energy dB
# 259 | 't' |   18ms | 0.7%voiced | 414.5hz |  60.1RMS Energy dB
# 260 | 'h' |   22ms | 0.5%voiced | 385.0hz |  67.1RMS Energy dB
# 261 | 'i' |   14ms | 0.6%voiced | 429.5hz |  72.6RMS Energy dB
# 262 | 's' |   58ms | 0.7%voiced | 439.8hz |  66.8RMS Energy dB
# 263 | ' ' |   68ms | 0.4%voiced | 385.0hz | 110.8RMS Energy dB
# 264 | 'n' |   10ms | 0.3%voiced | 411.5hz |  86.8RMS Energy dB
# 265 | 'e' |   54ms | 0.4%voiced | 400.2hz |  49.8RMS Energy dB
# 266 | 'w' |   56ms | 0.9%voiced | 481.0hz |  63.9RMS Energy dB
# 267 | ' ' |   46ms | 0.9%voiced | 397.2hz |  58.6RMS Energy dB
# 268 | 'b' |   23ms | 0.7%voiced | 406.5hz |  50.3RMS Energy dB
# 269 | 'e' |   32ms | 0.3%voiced | 371.8hz |  51.6RMS Energy dB
# 270 | 'i' |   56ms | 0.9%voiced | 481.0hz |  51.3RMS Energy dB
# 271 | 'n' |   41ms | 1.0%voiced | 530.5hz |  64.4RMS Energy dB
# 272 | 'g' |   36ms | 0.9%voiced | 524.0hz |  51.2RMS Energy dB
# 273 | ' ' |   23ms | 0.7%voiced | 385.0hz |  48.8RMS Energy dB
# 274 | 'f' |   20ms | 0.7%voiced | 354.8hz |  46.6RMS Energy dB
# 275 | 'i' |   75ms | 0.5%voiced | 346.5hz |  48.3RMS Energy dB
# 276 | 'n' |  133ms | 1.0%voiced | 422.8hz |  52.4RMS Energy dB
# 277 | 'd' |   37ms | 1.0%voiced | 321.8hz |  58.7RMS Energy dB
# 278 | ' ' |   13ms | 0.8%voiced | 295.2hz |  50.1RMS Energy dB
# 279 | 'a' |   11ms | 0.9%voiced | 295.2hz |  59.9RMS Energy dB
# 280 | 'c' |   65ms | 1.0%voiced | 309.2hz |  54.4RMS Energy dB
# 281 | 'c' |   35ms | 0.9%voiced | 286.0hz |  62.2RMS Energy dB
# 282 | 'e' |   80ms | 0.2%voiced | 356.0hz | 108.6RMS Energy dB
# 283 | 'p' |   55ms | 0.4%voiced | 304.5hz |  58.5RMS Energy dB
# 284 | 't' |   39ms | 0.0%voiced |   0.0hz |  77.9RMS Energy dB
# 285 | 'a' |   48ms | 0.2%voiced | 329.2hz |  73.5RMS Energy dB
# 286 | 'n' |   52ms | 0.8%voiced | 331.8hz |  81.9RMS Energy dB
# 287 | 'c' |   47ms | 0.2%voiced | 334.5hz |  61.4RMS Energy dB
# 288 | 'e' |   76ms | 0.2%voiced | 373.0hz |  87.2RMS Energy dB
# 289 | ' ' |    9ms | 0.7%voiced | 321.8hz |  62.2RMS Energy dB
# 290 | 'a' |   12ms | 0.9%voiced | 334.5hz |  61.2RMS Energy dB
# 291 | 'm' |   14ms | 1.0%voiced | 259.5hz |  51.9RMS Energy dB
# 292 | 'o' |   64ms | 1.0%voiced | 248.5hz |  51.2RMS Energy dB
# 293 | 'n' |   76ms | 0.9%voiced | 261.5hz |  50.7RMS Energy dB
# 294 | 'g' |   48ms | 0.9%voiced | 239.0hz |  45.8RMS Energy dB
# 295 | ' ' |   24ms | 0.6%voiced | 266.8hz |  57.8RMS Energy dB
# 296 | 't' |   13ms | 0.6%voiced | 286.0hz |  61.0RMS Energy dB
# 297 | 'h' |   14ms | 0.9%voiced | 292.8hz |  70.5RMS Energy dB
# 298 | 'e' |    9ms | 0.7%voiced | 329.2hz |  58.6RMS Energy dB
# 299 | ' ' |   38ms | 0.3%voiced | 320.5hz |  62.4RMS Energy dB
# 300 | 'P' |   89ms | 0.2%voiced | 305.8hz |  80.3RMS Energy dB
# 301 | 'o' |   56ms | 0.0%voiced |   0.0hz |  48.6RMS Energy dB
# 302 | 'n' |  188ms | 0.4%voiced | 303.2hz |  42.1RMS Energy dB
# 303 | 'i' |   35ms | 0.8%voiced | 279.5hz |  54.1RMS Energy dB
# 304 | 'e' |  303ms | 0.8%voiced | 343.8hz |  63.2RMS Energy dB
# 305 | 's' |   50ms | 0.2%voiced | 328.0hz |  67.9RMS Energy dB
# 306 | '?' |   71ms | 0.5%voiced | 329.2hz |  55.6RMS Energy dB
# 307 | ' ' |  218ms | 0.1%voiced |   0.0hz |  96.5RMS Energy dB
# 308 | 'A' |  154ms | 0.1%voiced |   0.0hz |  75.6RMS Energy dB
# 309 | 'n' |   76ms | 0.4%voiced | 339.8hz |  58.8RMS Energy dB
# 310 | 'd' |   38ms | 0.9%voiced | 403.5hz |  42.9RMS Energy dB
# 311 | ' ' |   14ms | 0.9%voiced | 379.0hz |  39.9RMS Energy dB
# 312 | 'h' |   15ms | 0.5%voiced | 373.0hz |  44.2RMS Energy dB
# 313 | 'o' |   34ms | 0.7%voiced | 386.5hz |  59.0RMS Energy dB
# 314 | 'w' |   66ms | 0.8%voiced | 398.8hz |  83.1RMS Energy dB
# 315 | ' ' |   41ms | 1.0%voiced | 438.0hz |  57.8RMS Energy dB
# 316 | 'w' |   43ms | 1.0%voiced | 417.8hz |  63.8RMS Energy dB
# 317 | 'i' |   34ms | 1.0%voiced | 453.5hz |  68.2RMS Energy dB
# 318 | 'l' |   17ms | 0.9%voiced | 520.0hz |  58.0RMS Energy dB
# 319 | 'l' |   32ms | 1.0%voiced | 580.0hz |  54.4RMS Energy dB
# 320 | ' ' |   56ms | 1.0%voiced | 510.0hz |  47.0RMS Energy dB
# 321 | 'h' |   21ms | 1.0%voiced | 457.2hz |  45.7RMS Energy dB
# 322 | 'i' |   10ms | 1.0%voiced | 443.0hz |  45.7RMS Energy dB
# 323 | 's' |   31ms | 0.9%voiced | 394.0hz |  43.0RMS Energy dB
# 324 | ' ' |   26ms | 0.6%voiced | 335.8hz |  63.4RMS Energy dB
# 325 | 'p' |   26ms | 0.1%voiced |   0.0hz |  99.2RMS Energy dB
# 326 | 'r' |   55ms | 0.3%voiced | 373.0hz |  65.4RMS Energy dB
# 327 | 'e' |   24ms | 0.9%voiced | 366.0hz |  53.8RMS Energy dB
# 328 | 's' |   60ms | 0.8%voiced | 571.0hz |  60.0RMS Energy dB
# 329 | 'e' |   70ms | 0.6%voiced | 414.5hz |  70.4RMS Energy dB
# 330 | 'n' |   39ms | 1.0%voiced | 538.5hz |  52.1RMS Energy dB
# 331 | 'c' |   48ms | 1.0%voiced | 339.8hz |  47.9RMS Energy dB
# 332 | 'e' |   55ms | 1.0%voiced | 282.8hz |  88.4RMS Energy dB
# 333 | ' ' |   11ms | 0.8%voiced | 320.5hz |  80.2RMS Energy dB
# 334 | 'c' |   19ms | 0.1%voiced | 388.0hz |  50.7RMS Energy dB
# 335 | 'h' |   98ms | 0.0%voiced |   0.0hz |  94.3RMS Energy dB
# 336 | 'a' |   30ms | 0.1%voiced |   0.0hz |  77.4RMS Energy dB
# 337 | 'n' |  127ms | 0.3%voiced | 245.6hz |  56.7RMS Energy dB
# 338 | 'g' |   41ms | 0.9%voiced | 295.2hz |  57.6RMS Energy dB
# 339 | 'e' |   42ms | 0.2%voiced | 290.5hz |  58.2RMS Energy dB
# 340 | ' ' |   15ms | 0.1%voiced |   0.0hz |  54.9RMS Energy dB
# 341 | 't' |   16ms | 0.1%voiced |   0.0hz |  58.3RMS Energy dB
# 342 | 'h' |    9ms | 0.1%voiced |   0.0hz |  37.0RMS Energy dB
# 343 | 'e' |   13ms | 0.1%voiced |   0.0hz |  56.9RMS Energy dB
# 344 | ' ' |   32ms | 0.4%voiced | 319.2hz |  80.9RMS Energy dB
# 345 | 'c' |   46ms | 0.2%voiced | 335.8hz |  65.6RMS Energy dB
# 346 | 'o' |   30ms | 0.3%voiced | 334.5hz |  58.2RMS Energy dB
# 347 | 'u' |   51ms | 0.8%voiced | 314.2hz |  51.3RMS Energy dB
# 348 | 'r' |   25ms | 0.5%voiced | 379.0hz |  55.5RMS Energy dB
# 349 | 's' |   41ms | 0.8%voiced | 380.5hz |  58.0RMS Energy dB
# 350 | 'e' |   81ms | 0.9%voiced | 304.5hz |  95.2RMS Energy dB
# 351 | ' ' |    9ms | 1.0%voiced | 514.0hz |  74.2RMS Energy dB
# 352 | 'o' |   13ms | 1.0%voiced | 400.2hz |  68.9RMS Energy dB
# 353 | 'f' |   26ms | 0.9%voiced | 421.2hz |  40.8RMS Energy dB
# 354 | ' ' |   38ms | 0.9%voiced | 329.2hz |  32.7RMS Energy dB
# 355 | 'e' |   25ms | 0.5%voiced | 305.8hz |  47.3RMS Energy dB
# 356 | 'v' |   53ms | 0.9%voiced | 331.8hz |  60.2RMS Energy dB
# 357 | 'e' |   77ms | 0.5%voiced | 305.8hz |  27.3RMS Energy dB
# 358 | 'n' |   75ms | 1.0%voiced | 335.8hz |  56.6RMS Energy dB
# 359 | 't' |   56ms | 1.0%voiced | 352.0hz |  71.3RMS Energy dB
# 360 | 's' |    9ms | 0.9%voiced | 304.5hz |  77.0RMS Energy dB
# 361 | ' ' |   21ms | 0.3%voiced | 307.0hz |  81.9RMS Energy dB
# 362 | 'a' |   10ms | 0.4%voiced | 279.5hz |  58.3RMS Energy dB
# 363 | 's' |   35ms | 0.9%voiced | 239.0hz |  47.9RMS Energy dB
# 364 | ' ' |   79ms | 1.0%voiced | 215.1hz |  50.5RMS Energy dB
# 365 | 'w' |   33ms | 0.9%voiced | 226.2hz |  53.5RMS Energy dB
# 366 | 'e' |   26ms | 0.9%voiced | 237.1hz |  50.8RMS Energy dB
# 367 | ' ' |   21ms | 1.0%voiced | 262.5hz |  59.6RMS Energy dB
# 368 | 'k' |   24ms | 1.0%voiced | 237.1hz |  55.9RMS Energy dB
# 369 | 'n' |   10ms | 0.9%voiced | 282.8hz |  56.9RMS Energy dB
# 370 | 'o' |   55ms | 1.0%voiced | 297.5hz |  62.6RMS Energy dB
# 371 | 'w' |   86ms | 0.8%voiced | 266.8hz |  60.2RMS Energy dB
# 372 | ' ' |   56ms | 0.9%voiced | 270.8hz |  44.0RMS Energy dB
# 373 | 't' |   34ms | 0.9%voiced | 251.5hz |  54.9RMS Energy dB
# 374 | 'h' |   35ms | 0.7%voiced | 234.4hz |  69.2RMS Energy dB
# 375 | 'e' |   42ms | 0.8%voiced | 262.5hz |  55.7RMS Energy dB
# 376 | 'm' |   72ms | 0.8%voiced | 270.8hz |  53.9RMS Energy dB
# 377 | '?' |   92ms | 0.9%voiced | 290.5hz |  69.9RMS Energy dB
# 378 | ' ' |  219ms | 0.4%voiced | 297.5hz | 108.9RMS Energy dB
# 379 | 'O' |   99ms | 0.2%voiced | 291.8hz |  78.2RMS Energy dB
# 380 | 'n' |  107ms | 0.6%voiced | 291.8hz |  50.3RMS Energy dB
# 381 | 'l' |   48ms | 0.9%voiced | 376.0hz |  36.6RMS Energy dB
# 382 | 'y' |   38ms | 0.9%voiced | 264.5hz |  52.5RMS Energy dB
# 383 | ' ' |   75ms | 0.8%voiced | 290.5hz |  45.1RMS Energy dB
# 384 | 't' |   54ms | 0.8%voiced | 337.0hz |  72.4RMS Energy dB
# 385 | 'i' |   62ms | 0.2%voiced | 287.2hz |  59.1RMS Energy dB
# 386 | 'm' |  109ms | 0.6%voiced | 234.4hz |  51.8RMS Energy dB
# 387 | 'e' |   42ms | 0.6%voiced | 244.8hz |  47.3RMS Energy dB
# 388 | ' ' |   19ms | 0.3%voiced | 171.5hz |  37.1RMS Energy dB
# 389 | 'w' |   12ms | 0.2%voiced | 158.0hz |  39.4RMS Energy dB
# 390 | 'i' |   15ms | 0.8%voiced | 297.5hz |  49.0RMS Energy dB
# 391 | 'l' |   10ms | 1.0%voiced | 316.8hz |  68.0RMS Energy dB
# 392 | 'l' |    9ms | 1.0%voiced | 320.5hz |  60.0RMS Energy dB
# 393 | ' ' |   10ms | 0.5%voiced | 197.4hz |  45.8RMS Energy dB
# 394 | 't' |    9ms | -0.0%voiced |   0.0hz |   0.7RMS Energy dB
# 395 | 'e' |    9ms | 0.1%voiced |  94.3hz |  24.8RMS Energy dB
# 396 | 'l' |   17ms | -0.0%voiced |   0.0hz |   8.9RMS Energy dB
# 397 | 'l' |    9ms | -0.0%voiced |   0.0hz |  10.7RMS Energy dB
# 398 | '!' |    9ms | 0.0%voiced |   0.0hz |   1.6RMS Energy dB

# %% [markdown]
# ---
